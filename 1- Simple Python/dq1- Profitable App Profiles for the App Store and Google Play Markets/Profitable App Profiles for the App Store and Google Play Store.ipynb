# %% [markdown]
# # What kind of Apps generate the most profit?

# %% [markdown]
# ## Introduction:
#    We only build apps that are free to download and install, and our main source of revenue consists of in-app ads. This means our revenue for any given app is mostly influenced by the number of users who use our app — the more users that see and engage with the ads, the better.
#    As of September 2018, there were approximately 2 million iOS apps available on the App Store, and 2.1 million Android apps on Google Play.
#
# ![blog-12](blog-12.jpg)
#
# ## Goal:
#    Our goal for this project is to analyze data to help our developers understand what type of apps are likely to attract more users.
#
# ## Resources:
#    Collecting data for over 4 million apps requires a significant amount of time and money, so we'll try to analyze a sample of the data instead. To avoid spending resources on collecting new data ourselves, we should first try to see if we can find any relevant existing data at no cost. Luckily, these are two data sets that seem suitable for our goals
# - A dataset containing ~10,000 Android apps from Google Play. Data was collected in August 2018.                              [Here is the link](https://dq-content.s3.amazonaws.com/350/googleplaystore.csv)
# - A dataset containing ~7,000 iOS apps from App Store. Data was collected in July 2017.                                        [Here is the link](https://dq-content.s3.amazonaws.com/350/AppleStore.csv)

# %% [markdown]
# ---

# %% [markdown]
# ## Exploring the Data

# %% [markdown]
# Lets create an 'explore' function to look into the dataset

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    '''
    Peeks into the dataset
    
    Args:
        dataset:list of the lists
        start: int, representing the starting 
           indice of the slice
        end: int, representing the ending indice
          of the slice
        rows_and_columns: bool, has False value by 
        default. 
        
    Returns:
        Rows of the Dataset. If Arg `rows_and_columns' 
        is True, it also returns number of 
        rows and columns
        '''
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n')

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %% [markdown]
# ### Lets use csv module to load the dataset

# %%
from csv import reader 
# The Google Play data set 
open_file = open('googleplaystore.csv',encoding="utf8")
read_file = reader(open_file)
android = list(read_file)
android_header = android[0] # Separate the header row
android = android[1:]

# The App Store data set
open_file = open('AppleStore.csv',encoding="utf8")
read_file = reader(open_file)
apple = list(read_file)
apple_header = apple[0]    # Separate the header row
apple = apple[1:]

# %%
explore_data(android,0,5, True) # The PlayStore Data
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# Number of rows: 10841
# Number of columns: 13

# %%
explore_data(apple, 0, 5, True) # The AppStore Data
# Out:
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']
#
#
# Number of rows: 7197
# Number of columns: 16

# %%
print(android_header)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %%
print(apple_header)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Detect **inaacurate data**, and correct or remove it.

# %% [markdown]
# The Google Play data set has a [dedicated discussion](https://www.kaggle.com/lava18/google-play-store-apps/discussion) section where an error for a certain row has been described. The row 10472 has been highlighted as it does not have the Category details which has made the colums shift.
# This entry has missing `Rating` and a column shift happened for next columns..

# %%
print(android[10472])
print('\n')
print(android_header)
print(len(android[10472]))
print(len(android_header))
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
#
#
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# 12
# 13

# %% [markdown]
# The `rating` of 19 is invalid.

# %%
# Removal of the entry
del android[10472]

# %% [markdown]
# #### Detect **duplicate data**, and remove the duplicates.

# %% [markdown]
# Its important to check for the duplicates in our data

# %%
# lets check our data for duplicate entries through a for loop

duplicate_entries = [] # a new list for duplicate entries
unique_entries = [] # a list to contain unique entries

for row in android: # iterate through the rows, 
    name = row[0]   # within each row, go for the name.
    if name in unique_entries: # if name already exists in unique_entries... ,
        duplicate_entries.append(name) # append it to duplicate_entries.
    else: # Or if it never existed in unique_entries, then it must be unique.
        unique_entries.append(name) # Add it into the list of unique_entries
        
print('Number of Duplicate entries:\n{}'.format(len(
    duplicate_entries)))
print('\n')
print('Starting 5 entries:\n{}'.format(duplicate_entries[:5]))
# Out:
# Number of Duplicate entries:
# 1181
#
#
# Starting 5 entries:
# ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings']

# %% [markdown]
# - We have around 1181 Duplicate entries. Lets dive in further into one of those

# %%
for row in android: # Iterate through every row
    name = row[0] # Go for the name inside a row i-e. the first item,
    if name == 'Quick PDF Scanner + OCR FREE': # if name=='X'
        print(row) # print the entire row with name 'X'
# Out:
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80805', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80805', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80804', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']

# %% [markdown]
# Since the number of `reviews` validate the `ratings`, we want to keep the row with maximum `reviews`. For that purpose, lets make a dictionary that will keep the `name` and the **maximum** `reviews` for us.

# %%
reviews_max = {} # Make a new dictionary.
for row in android:  # Iterate through each row of the dataset
    name = row[0] # Assign variable to the first element of each row, that is its name.
    n_reviews = float(row[3]) # Each of the 3rd element of the row tells about the number of reviews, convert it into floats assign it to n_reviews
    if name in reviews_max and reviews_max[name] < n_reviews: # if the name already existed in our newly built dictionary, and a lower n_reviews number, then... 
        reviews_max[name] = n_reviews # Replace it with the bigger number
    else: # else,
        reviews_max[name] = n_reviews # leave it as it is.

# %%
reviews_max
# Out:
# {'Photo Editor & Candy Camera & Grid & ScrapBook': 159.0,
#  'Coloring book moana': 974.0,
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps': 87510.0,
#  'Sketch - Draw & Paint': 215644.0,
#  'Pixel Draw - Number Art Coloring Book': 967.0,
#  'Paper flowers instructions': 167.0,
#  'Smoke Effect Photo Maker - Smoke Editor': 178.0,
#  'Infinite Painter': 36815.0,
#  'Garden Coloring Book': 13791.0,
#  'Kids Paint Free - Drawing Fun': 121.0,
#  'Text on Photo - Fonteee': 13880.0,
#  'Name Art Photo Editor - Focus n Filters': 8788.0,
#  'Tattoo Name On My Photo Editor': 44829.0,
#  'Mandala Coloring Book': 4326.0,
#  '3D Color Pixel by Number - Sandbox Art Coloring': 1518.0,
#  'Learn To Draw Kawaii Characters': 55.0,
#  'Photo Designer - Write your name with shapes': 3632.0,
#  '350 Diy Room Decor Ideas': 27.0,
#  'FlipaClip - Cartoon animation': 194216.0,
#  'ibis Paint X': 224399.0,
#  'Logo Maker - Small Business': 450.0,
#  "Boys Photo Editor - Six Pack & Men's Suit": 654.0,
#  'Superheroes Wallpapers | 4K Backgrounds': 7699.0,
#  'Mcqueen Coloring pages': 65.0,
#  'HD Mickey Minnie Wallpapers': 118.0,
#  'Harley Quinn wallpapers HD': 192.0,
#  'Colorfit - Drawing & Coloring': 20260.0,
#  'Animated Photo Editor': 203.0,
#  'Pencil Sketch Drawing': 136.0,
#  'Easy Realistic Drawing Tutorial': 223.0,
#  'Pink Silver Bow Keyboard Theme': 1120.0,
#  'Art Drawing Ideas': 227.0,
#  'Anime Manga Coloring Book': 5035.0,
#  'Easy Origami Ideas': 1015.0,
#  'I Creative Idea': 353.0,
#  'How to draw Ladybug and Cat Noir': 564.0,
#  'UNICORN - Color By Number & Pixel Art Coloring': 8264.0,
#  'Floor Plan Creator': 36639.0,
#  'PIP Camera - PIP Collage Maker': 158.0,
#  'How To Color Disney Princess - Coloring Pages': 591.0,
#  'Drawing Clothes Fashion Ideas': 117.0,
#  'Sad Poetry Photo Frames 2018': 176.0,
#  'Textgram - write on photos': 295237.0,
#  'Paint Splash!': 2206.0,
#  'Popsicle Sticks and Similar DIY Craft Ideas': 26.0,
#  'Canva: Poster, banner, card maker & graphic design': 174531.0,
#  'Install images with music to make video without Net - 2018': 1070.0,
#  'Little Teddy Bear Colouring Book Game': 85.0,
#  'How To Draw Food': 845.0,
#  'Monster Truck Stunt 3D 2019': 367.0,
#  'Real Tractor Farming': 1598.0,
#  'Ultimate F1 Racing Championship': 284.0,
#  'Used Cars and Trucks for Sale': 17057.0,
#  'American Muscle Car Race': 129.0,
#  'Offroad Oil Tanker Driver Transport Truck 2019': 542.0,
#  'Tickets SDA 2018 and Exam from the State Traffic Safety Inspectorate with Drom.ru': 10479.0,
#  'Gas Prices (Germany only)': 805.0,
#  'Extreme Rally Championship': 129.0,
#  'Restart Navigator': 1403.0,
#  'REG - Check the regnumber, find information about Swedish vehicles': 3971.0,
#  'CityBus Lviv': 534.0,
#  'CDL Practice Test 2018 Edition': 7774.0,
#  'ezETC (ETC balance inquiry, meter trial, real-time traffic)': 38846.0,
#  'Free VIN Report for Used Cars': 2431.0,
#  'DMV Permit Practice Test 2018 Edition': 6090.0,
#  'Check Vehicle Tax': 295.0,
#  'Used Cars Mexico': 190.0,
#  'Ulysse Speedometer': 40211.0,
#  'REPUVE': 356.0,
#  'Used cars for sale - Trovit': 52530.0,
#  'Fines of the State Traffic Safety Inspectorate are official: inspection, payment of fines': 116986.0,
#  'SK Enca Direct Malls - Used Cars Search': 1379.0,
#  'Android Auto - Maps, Media, Messaging & Voice': 271920.0,
#  'PDD-UA': 736.0,
#  'Tickets SDA 2019 + Exam RF': 7021.0,
#  'Super Cars Wallpapers And Backgrounds': 197.0,
#  'Police Lights, Sirens & Follow Me': 737.0,
#  'Police Detector (Speed Camera Radar)': 3574.0,
#  'Best Car Wallpapers': 994.0,
#  'Tickets + PDA 2018 Exam': 197136.0,
#  'Pick Your Part Garage': 142.0,
#  'PakWheels: Buy & Sell Cars': 15168.0,
#  'Supervision service': 2155.0,
#  'Speed Camera Detector - Traffic & Speed Alert': 138.0,
#  'Used car search Goo net whole car Go to net': 5414.0,
#  'CarMax – Cars for Sale: Search Used Car Inventory': 21777.0,
#  'BEST CAR SOUNDS': 348.0,
#  'RST - Sale of cars on the PCT': 250.0,
#  'AutoScout24 Switzerland – Find your new car': 13372.0,
#  'Zona Azul Digital Fácil SP CET - OFFICIAL São Paulo': 7880.0,
#  'SMS Park': 3617.0,
#  'SKencar': 4806.0,
#  'Fuelio: Gas log & costs': 65786.0,
#  'auto fines': 31433.0,
#  'Used car is the first car - used car purchase, used car quotation, dealer information to': 5097.0,
#  'All of the parking lot - National Park application (parking lot search / parking sharing / discount payment)': 1754.0,
#  'Inquiry Fines and Debits of Vehicles': 2680.0,
#  'Gas Station': 1288.0,
#  'Hush - Beauty for Everyone': 18900.0,
#  'ipsy: Makeup, Beauty, and Tips': 49790.0,
#  'Natural recipes for your beauty': 1150.0,
#  'BestCam Selfie-selfie, beauty camera, photo editor': 1739.0,
#  'Mirror - Zoom & Exposure -': 32090.0,
#  'Beauty Selfie Camera': 2225.0,
#  'Hairstyles step by step': 4369.0,
#  'Filters for Selfie': 8572.0,
#  'Tie - Always be happy': 964.0,
#  'Ulta Beauty': 42050.0,
#  'Prom MakeUp Tutorial': 104.0,
#  'Selfie Camera': 17934.0,
#  'Sweet Selfie Beauty Camera': 601.0,
#  'Colors of white in Urdu': 36.0,
#  'Selfie Camera Photo Editor & Filter & Sticker': 187.0,
#  'Wrinkles and rejuvenation': 182.0,
#  'Eyes Makeup Beauty Tips': 30.0,
#  'Photo Editor 2018': 134.0,
#  'Step By Step Eyes Makeup Tutorial': 74.0,
#  'Beauty Camera - Selfie Camera': 113715.0,
#  'Girls Hairstyles': 3595.0,
#  'Mirror Camera (Mirror + Selfie Camera)': 9315.0,
#  'Beauty Tips - Beauty Tips in Sinhala': 75.0,
#  'Haircut Tutorials/Haircut Videos': 38.0,
#  'Sephora: Skin Care, Beauty Makeup & Fragrance Shop': 26834.0,
#  'Manicure - nail design': 119.0,
#  'Sticker Camera - Selfie Filters, Beauty Camera': 2277.0,
#  'Filters for B Live': 2280.0,
#  'Skin Care and Natural Beauty': 654.0,
#  'Facial Wrinkle Reduction': 184.0,
#  'Makeup Videos': 9.0,
#  'Secrets of beauty, youth and health': 77.0,
#  'Recipes and tips for losing weight': 35.0,
#  'Discover Color': 364.0,
#  'Eyeliner step by step 2018': 18.0,
#  'Dresses Ideas & Fashions +3000': 473.0,
#  'Lady adviser (beauty, health)': 30.0,
#  'Step By Step Hairstyles For Women': 66.0,
#  'Rainbow Camera': 3871.0,
#  'Methods of teeth whitening': 257.0,
#  'Girls hairstyles 2018': 62.0,
#  'Wattpad 📖 Free Books': 2915189.0,
#  'E-Book Read - Read Book for free': 1857.0,
#  'Download free book with green book': 4478.0,
#  'Wikipedia': 577550.0,
#  'Amazon Kindle': 814151.0,
#  'Cool Reader': 246315.0,
#  'Dictionary - Merriam-Webster': 454412.0,
#  'NOOK: Read eBooks & Magazines': 155466.0,
#  'Free Panda Radio Music': 418.0,
#  'Book store': 22486.0,
#  'FBReader: Favorite Book Reader': 203130.0,
#  'English Grammar Complete Handbook': 1435.0,
#  'Free Books - Spirit Fanfiction and Stories': 116507.0,
#  'Google Play Books': 1433233.0,
#  'AlReader -any text book reader': 90468.0,
#  'Offline English Dictionary': 860.0,
#  'Oxford Dictionary of English : Free': 364452.0,
#  'Offline: English to Tagalog Dictionary': 967.0,
#  'Spanish English Translator': 87919.0,
#  'FamilySearch Tree': 17506.0,
#  'Cloud of Books': 1862.0,
#  'Recipes of Prophetic Medicine for free': 2084.0,
#  'ReadEra – free ebook reader': 47303.0,
#  'NOOK App for NOOK Devices': 19090.0,
#  'Anonymous caller detection': 161.0,
#  'Ebook Reader': 85842.0,
#  'Litnet - E-books': 7831.0,
#  'Read books online': 91615.0,
#  'English to Urdu Dictionary': 4620.0,
#  'eBoox: book reader fb2 epub zip': 21336.0,
#  'English Persian Dictionary': 26875.0,
#  'Flybook': 1778.0,
#  'All Maths Formulas': 2709.0,
#  'Ancestry': 64513.0,
#  'HTC Help': 8342.0,
#  'English translation from Bengali': 527.0,
#  'Pdf Book Download - Read Pdf Book': 1322.0,
#  'Free Book Reader': 1680.0,
#  'eBoox new: Reader for fb2 epub zip books': 2739.0,
#  'Only 30 days in English, the guideline is guaranteed': 1065.0,
#  'Moon+ Reader': 233757.0,
#  "SH-02J Owner's Manual (Android 8.0)": 2.0,
#  'English-Myanmar Dictionary': 8788.0,
#  'Golden Dictionary (EN-AR)': 51269.0,
#  'All Language Translator Free': 30105.0,
#  'Azpen eReader': 156.0,
#  'URBANO V 02 instruction manual': 114.0,
#  'English Dictionary - Offline': 341234.0,
#  'Visual Voicemail by MetroPCS': 16129.0,
#  'Indeed Job Search': 674730.0,
#  'Uber Driver': 1254730.0,
#  'ADP Mobile Solutions': 85185.0,
#  'Snag - Jobs Hiring Now': 32584.0,
#  'Docs To Go™ Free Office Suite': 217730.0,
#  'Google My Business': 70991.0,
#  'OfficeSuite : Free Office + PDF Editor': 1002859.0,
#  'USPS MOBILE®': 16589.0,
#  'Job Search by ZipRecruiter': 148945.0,
#  'Curriculum vitae App CV Builder Free Resume Maker': 4571.0,
#  'Google Primer': 62272.0,
#  'Alba Heaven - Alvarez Job Portal Services': 8941.0,
#  'SuperLivePro': 46353.0,
#  'Facebook Pages Manager': 1279800.0,
#  'OfficeSuite Pro + PDF (Trial)': 88073.0,
#  'My Space - Employment Center': 67000.0,
#  'Box': 159872.0,
#  'Polaris Office for LG': 30847.0,
#  'Call Blocker': 17529.0,
#  'Jobs in Alabama - Jobs in Alba': 11622.0,
#  'Square Point of Sale - POS': 95912.0,
#  'Plugin:AOT v5.0': 4034.0,
#  'Kariyer.net': 45964.0,
#  'SEEK Job Search': 14955.0,
#  'Become a Job - Find a job or advertise': 6903.0,
#  'ZOOM Cloud Meetings': 31614.0,
#  'Easy Installer - Apps On SD': 23055.0,
#  'Facebook Ads Manager': 19051.0,
#  'IndiaMART: Search Products, Buy, Sell & Trade': 207372.0,
#  'ViettelPost express delivery': 1225.0,
#  'MyASUS - Service Center': 380837.0,
#  'Job Korea - Career Jobs': 10600.0,
#  '104 Looking for a job - looking for a job, looking for a job, looking for a part-time job, health checkup, resume, treatment room': 74359.0,
#  'Myanmar 2D/3D': 822.0,
#  'Quick PDF Scanner + OCR FREE': 80804.0,
#  'sABN': 2287.0,
#  'ATI Cargoes and Transportation': 4162.0,
#  'Secure Folder': 14760.0,
#  'UPS Mobile': 23243.0,
#  'Y! Mobile menu': 9.0,
#  'SignEasy | Sign and Fill PDF and other Documents': 8978.0,
#  'Genius Scan - PDF Scanner': 42492.0,
#  'Tiny Scanner - PDF Scanner App': 286897.0,
#  'Fast Scanner : Free PDF Scan': 103755.0,
#  'Mobile Doc Scanner (MDScan) Lite': 46505.0,
#  'TurboScan: scan documents and receipts in PDF': 11442.0,
#  'Tiny Scanner Pro: PDF Doc Scan': 10295.0,
#  'Zenefits': 296.0,
#  'Google Ads': 29331.0,
#  'Slack': 51510.0,
#  'FreshBooks Classic': 1802.0,
#  'Insightly CRM': 1383.0,
#  'QuickBooks Accounting: Invoicing & Expenses': 23175.0,
#  'HipChat - Chat Built for Teams': 5868.0,
#  'Xero Accounting Software': 2111.0,
#  'MailChimp - Email, Marketing Automation': 5448.0,
#  'Crew - Free Messaging and Scheduling': 4159.0,
#  'Asana: organize team projects': 20815.0,
#  'Google Analytics': 78662.0,
#  'AdWords Express': 7149.0,
#  'Accounting App - Zoho Books': 3079.0,
#  'Invoice & Time Tracking - Zoho': 5800.0,
#  'join.me - Simple Meetings': 6989.0,
#  'Invoice 2go — Professional Invoices and Estimates': 16422.0,
#  'Cisco Webex Meetings': 108741.0,
#  'ScreenMeet. Easy Phone Meeting': 624.0,
#  'Cisco Webex Teams': 1661.0,
#  'Microsoft Remote Desktop': 97702.0,
#  'Start Meeting': 308.0,
#  'ClickMeeting Webinars': 5211.0,
#  'BlueJeans for Android': 1058.0,
#  'Skype for Business for Android': 78172.0,
#  'Verify - Receipts & Expenses': 413.0,
#  'LINE WEBTOON - Free Comics': 1013944.0,
#  'Manga Master - Best manga & comic reader': 24005.0,
#  'GANMA! - All original stories free of charge for all original comics': 57106.0,
#  'Röhrich Werner Soundboard': 2249.0,
#  'Unicorn Pokez - Color By Number': 516.0,
#  'MangaToon - Comics updated Daily': 834.0,
#  'Manga Net – Best Online Manga Reader': 1010.0,
#  'Manga Rock - Best Manga Reader': 238970.0,
#  'Manga - read Thai translation': 302.0,
#  'The Vietnam Story - Fun Stories': 438.0,
#  'Dragon Ball Wallpaper - Ringtones': 73.0,
#  'Funny Jokes Photos': 39.0,
#  'Truyện Vui Tý Quậy': 144.0,
#  'Comic Es - Shojo manga / love comics free of charge ♪ ♪': 2181.0,
#  'comico Popular Original Cartoon Updated Everyday Comico': 93965.0,
#  'Daily Manga - Comic & Webtoon': 1462.0,
#  '漫咖 Comics - Manga,Novel and Stories': 12088.0,
#  'Emmanuella Funny Videos 2018': 314.0,
#  'DC Comics': 25673.0,
#  'Manga Zero - Japanese cartoon and comic reader': 15194.0,
#  'Marvel Unlimited': 22551.0,
#  'Tapas – Comics, Novels, and Stories': 29839.0,
#  "Children's cartoons (Mithu-Mina-Raju)": 279.0,
#  "Narrator's Voice": 564387.0,
#  '【Ranobbe complete free】 Novelba - Free app that you can read and write novels': 1330.0,
#  'Faustop Sounds': 1677.0,
#  'Manga Mania - Best online manga reader': 757.0,
#  '- Free Comics - Comic Apps': 115.0,
#  'Manga AZ - Manga Comic Reader': 126.0,
#  'Buff Thun - Daily Free Webtoon / Comics / Web Fiction / Mini Game': 9952.0,
#  "pixiv comic - everyone's manga app": 18814.0,
#  'Funny Jokes and Stories 2018': 21.0,
#  'Hojiboy Tojiboyev Life Hacks': 15.0,
#  'Perfect Viewer': 51981.0,
#  'Best Wallpapers Backgrounds(100,000+ 4K HD)': 3596.0,
#  'think Comics': 1006.0,
#  'Memes Button': 5968.0,
#  'Laftel - Watching and Announcing Snooping, Streaming': 4895.0,
#  'Messenger – Text and Video Chat for Free': 56642847.0,
#  'WhatsApp Messenger': 69109672.0,
#  'Messenger for SMS': 125257.0,
#  'Google Chrome: Fast & Secure': 9642112.0,
#  'Messenger Lite: Free Calls & Messages': 1429038.0,
#  'Gmail': 4604324.0,
#  'Hangouts': 3419464.0,
#  'Viber Messenger': 11335481.0,
#  'My Tele2': 158679.0,
#  'Firefox Browser fast & private': 3075096.0,
#  'Yahoo Mail – Stay Organized': 4188345.0,
#  'imo beta free calls and text': 659395.0,
#  'imo free video calls and chat': 4785892.0,
#  'Contacts': 66602.0,
#  'Call Free – Free Call': 30209.0,
#  'Web Browser & Explorer': 36901.0,
#  'Opera Mini - fast web browser': 5150801.0,
#  'Browser 4G': 192948.0,
#  'MegaFon Dashboard': 99559.0,
#  'ZenUI Dialer & Contacts': 437674.0,
#  'Cricket Visual Voicemail': 13698.0,
#  'Opera Browser: Fast and Secure': 2473795.0,
#  'TracFone My Account': 20769.0,
#  'Firefox Focus: The privacy browser': 36981.0,
#  'Google Voice': 171052.0,
#  'Chrome Dev': 63576.0,
#  'Xperia Link™': 45487.0,
#  'TouchPal Keyboard - Fun Emoji & Android Keyboard': 615381.0,
#  'Who': 2451093.0,
#  'Skype Lite - Free Video Call & Chat': 33053.0,
#  'WeChat': 5387631.0,
#  'UC Browser Mini -Tiny Fast Private & Secure': 3648765.0,
#  'WhatsApp Business': 137144.0,
#  'My magenta': 42370.0,
#  'Android Messages': 781810.0,
#  'Telegram': 3128611.0,
#  'Google Duo - High Quality Video Calls': 2083237.0,
#  'Puffin Web Browser': 541661.0,
#  'Seznam.cz': 46702.0,
#  'Antillean Gold Telegram (original version)': 2939.0,
#  'AT&T Visual Voicemail': 13761.0,
#  'GMX Mail': 258556.0,
#  'Omlet Chat': 40751.0,
#  'UC Browser - Fast Download Private & Secure': 17712922.0,
#  'My Vodacom SA': 25021.0,
#  'Microsoft Edge': 27156.0,
#  'Hangouts Dialer - Call Phones': 122512.0,
#  'Talkatone: Free Texts, Calls & Phone Number': 132015.0,
#  'Calls & Text by Mo+': 83239.0,
#  'free video calls and chat': 594720.0,
#  'Skype - free IM & video calls': 10484169.0,
#  'GO SMS Pro - Messenger, Free Themes, Emoji': 2876500.0,
#  'Messaging+ SMS, MMS Free': 28238.0,
#  'chomp SMS': 335646.0,
#  'Glide - Video Chat Messenger': 350154.0,
#  'Text SMS': 349384.0,
#  'Google Allo': 347086.0,
#  'Talkray - Free Calls & Texts': 244863.0,
#  'LINE: Free Calls & Messages': 10790092.0,
#  'GroupMe': 330761.0,
#  'mysms SMS Text Messaging Sync': 37320.0,
#  'BBM - Free Calls & Messages': 12843436.0,
#  'KakaoTalk: Free Calls & Text': 2546549.0,
#  '2ndLine - Second Phone Number': 15880.0,
#  'CM Browser - Ad Blocker , Fast Download , Privacy': 2265084.0,
#  'Ninesky Browser': 42925.0,
#  'Dolphin Browser - Fast, Private & Adblock🐬': 2511130.0,
#  'Ghostery Privacy Browser': 13100.0,
#  'InBrowser - Incognito Browsing': 27156.0,
#  'Web Browser for Android': 55110.0,
#  'DU Browser—Browse fast & fun': 1133539.0,
#  'Lightning Web Browser': 12578.0,
#  'Web Browser': 10965.0,
#  'Puffin Browser Pro': 18247.0,
#  'Contacts+': 190613.0,
#  'ExDialer - Dialer & Contacts': 125232.0,
#  'PHONE for Google Voice & GTalk': 72065.0,
#  'Safest Call Blocker': 27540.0,
#  'Full Screen Caller ID': 104990.0,
#  'Hiya - Caller ID & Block': 177703.0,
#  'Mr. Number-Block calls & spam': 177263.0,
#  'Should I Answer?': 237468.0,
#  'RocketDial Dialer & Contacts': 32254.0,
#  'CallApp: Caller ID, Blocker & Phone Call Recorder': 483782.0,
#  'Whoscall - Caller ID & Block': 552635.0,
#  'CIA - Caller ID & Call Blocker': 60308.0,
#  'Calls Blacklist - Call Blocker': 457283.0,
#  'Call Control - Call Blocker': 93825.0,
#  'True Contact - Real Caller ID': 32283.0,
#  'Video Caller Id': 15287.0,
#  'Sync.ME – Caller ID & Block': 205739.0,
#  'Burner - Free Phone Number': 14873.0,
#  'Truecaller: Caller ID, SMS spam blocking & Dialer': 7820775.0,
#  'Caller ID +': 9498.0,
#  'K-9 Mail': 88427.0,
#  'myMail – Email for Hotmail, Gmail and Outlook Mail': 305218.0,
#  'Email TypeApp - Mail App': 183374.0,
#  'All Email Providers': 20901.0,
#  'Newton Mail - Email App for Gmail, Outlook, IMAP': 122595.0,
#  'GO Notifier': 124346.0,
#  'Mail.Ru - Email App': 837842.0,
#  'Mail1Click - Secure Mail': 255.0,
#  'Daum Mail - Next Mail': 41420.0,
#  'mail.com mail': 44706.0,
#  'SolMail - All-in-One email app': 23707.0,
#  'Vonage Mobile® Call Video Text': 29208.0,
#  'JusTalk - Free Video Calls and Fun Video Chat': 191032.0,
#  'Moco+ - Chat, Meet People': 1546.0,
#  'Calculator': 40770.0,
#  'Truth or Dare Pro': 0.0,
#  'Private Dating, Hide App- Blue for PrivacyHider': 0.0,
#  'Ad Blocker for SayHi': 4.0,
#  'AMBW Dating App: Asian Men Black Women Interracial': 2.0,
#  'Zoosk Dating App: Meet Singles': 516917.0,
#  'OkCupid Dating': 285838.0,
#  'Match™ Dating - Meet Singles': 76646.0,
#  'Hily: Dating, Chat, Match, Meet & Hook up': 2560.0,
#  'Hinge: Dating & Relationships': 7779.0,
#  'Casual Dating & Adult Singles - Joyride': 61637.0,
#  'BBW Dating & Plus Size Chat': 12633.0,
#  'Moco - Chat, Meet People': 313769.0,
#  'CMB Free Dating App': 48845.0,
#  'Hot or Not - Find someone right now': 305737.0,
#  'eharmony - Online Dating App': 31320.0,
#  'Free Dating App & Flirt Chat - Match with Singles': 172460.0,
#  'Chispa, the Dating App for Latino, Latina Singles': 4195.0,
#  'Clover Dating App': 11633.0,
#  'Black People Meet Singles Date': 10212.0,
#  'Mingle2 - Free Online Dating & Singles Chat Rooms': 37053.0,
#  'Free Dating App & Flirt Chat - Cheers': 667.0,
#  'stranger chat - anonymous chat': 13204.0,
#  'Blendr - Chat, Flirt & Meet': 28671.0,
#  'Free Dating Hook Up Messenger': 1157.0,
#  'Find Real Love — YouLove Premium Dating': 212626.0,
#  'Once - Quality Matches Every day': 222888.0,
#  'BLK - Swipe. Match. Chat.': 2067.0,
#  'Cougar Dating Life : Date Older Women Sugar Mummy': 1645.0,
#  'Howlr': 105.0,
#  'Stranger Chat & Date': 3414.0,
#  'Free Dating & Flirt Chat - Choice of Love': 42197.0,
#  'RandoChat - Chat roulette': 11806.0,
#  'BeWild Free Dating & Chat App': 1999.0,
#  'FastMeet: Chat, Dating, Love': 22545.0,
#  'Free Dating App - YoCutie - Flirt, Chat & Meet': 97699.0,
#  'OurTime Dating for Singles 50+': 2519.0,
#  'FarmersOnly Dating': 1145.0,
#  'Dating for 50 plus Mature Singles – FINALLY': 13049.0,
#  'Sudy – Meet Elite & Rich Single': 17268.0,
#  'Christian Dating For Free App': 8723.0,
#  'Just She - Top Lesbian Dating': 954.0,
#  'Single Parent Meet #1 Dating': 2593.0,
#  'EliteSingles – Dating for Single Professionals': 5377.0,
#  'Millionaire Match: Rich Singles Dating App': 853.0,
#  'InterracialCupid - Interracial Dating App': 212.0,
#  'Sugar Mommas Dating And Single Search': 1972.0,
#  'Hide App, Private Dating, Safe Chat - PrivacyHider': 35205.0,
#  'muzmatch: Muslim & Arab Singles, Marriage & Dating': 5168.0,
#  'NoBuffDating - Free Dating App': 1939.0,
#  'Sugar Daddy Dating App': 277.0,
#  'Adult Dirty Emojis': 80.0,
#  'Free Dating App - Meet Local Singles - Flirt Chat': 825.0,
#  'Meet4U - Chat, Love, Singles!': 40039.0,
#  'SnpCupid Dating': 1093.0,
#  'Chat Rooms, Avatars, Date - Galaxy': 135420.0,
#  'Adult Dating - AdultFinder': 1601.0,
#  'Gay Sugar Daddy Dating & Hookup – Sudy Gay': 2212.0,
#  'Meet24 - Love, Chat, Singles': 57083.0,
#  'BBWCupid - BBW Dating App': 241.0,
#  'ChatVideo Meet new people': 63986.0,
#  'TryDate - Free Online Dating App, Chat Meet Adults': 7888.0,
#  'Black White Interracial Dating - Interracial Match': 537.0,
#  'USA Singles Meet, Match and Date Free - Date': 5084.0,
#  'FlirtChat - ♥Free Dating/Flirting App♥': 2433.0,
#  'The League': 837.0,
#  'Herpes Dating: 1,000K+ Singles': 738.0,
#  'Heart mill': 4631.0,
#  '95Live -SG#1 Live Streaming App': 4954.0,
#  'Mutual - LDS Dating': 1439.0,
#  '2RedBeans': 337.0,
#  'SweetRing - Meet, Match, Date': 51698.0,
#  'BiggerCity: Chat for gay bears, chubs & chasers': 923.0,
#  'SilverSingles: The 50+ Dating App': 149.0,
#  'Herpes Positive Singles Dating': 198.0,
#  'Glam - Premium Dating App': 23170.0,
#  'iDates - Chats, Flirts, Dating, Love & Relations': 13890.0,
#  'JustDating': 13440.0,
#  'Interracial Match Dating App': 143.0,
#  'Russian Dating & Chat for Russian speaking RusDate': 1059.0,
#  'Sky People (SPI): A secure blind date through authentication by Seoul National University': 894.0,
#  'Sweet mi - unlimited hunnam hunting blind date': 6191.0,
#  'Mingle - Online Dating App to Chat & Meet People': 15081.0,
#  'BBW Dating & Curvy Singles Chat- LargeFriends': 218.0,
#  'Hitwe - meet people and chat': 243950.0,
#  'A hundred': 236.0,
#  'JustSayHi- Dating App. Chat & Meet Singles Nearby': 5152.0,
#  'FERZU - Furries Social Network': 1576.0,
#  'WannaMeet – Dating & Chat App': 6701.0,
#  'Luxy Pro- Elite Dating Single': 742.0,
#  'Dating Network': 187.0,
#  'Chatting - Free chat, random chat, boyfriend, girlfriend': 2506.0,
#  'iPair-Meet, Chat, Dating': 182986.0,
#  'Meet, chat & date. Free dating app - Chocolate app': 8661.0,
#  'Transenger – Ts Dating and Chat for Free': 8.0,
#  'O-Star': 59.0,
#  'Free Cam Girls - Live Webcam': 35.0,
#  'Cardi B Live Stream Video Chat - Prank': 28.0,
#  'Live Girls Talk - Free Video Chat': 125.0,
#  'Live Talk - Free Text and Video Chat': 185.0,
#  'Chat Kids - Chat Room For Kids': 6.0,
#  'Girls Live Chat - Free Text & Video Chat': 110.0,
#  'Random Video Chat': 3.0,
#  'MouseMingle': 3.0,
#  'American Girls Mobile Numbers': 5.0,
#  'Random Video Chat App With Strangers': 3.0,
#  'FREE VIDEO CHAT - LIVE VIDEO AND TEXT CHAT': 84.0,
#  'Awake Dating': 2.0,
#  'Live Chat - Free Video Chat Rooms': 20.0,
#  'Meet With Strangers: Video Chat & Dating': 2.0,
#  'FREE LIVE TALK': 776.0,
#  'Random Chat App with Strangers': 2.0,
#  'Ost. Zombies Cast - New Music and Lyrics': 1.0,
#  'Dating White Girls': 0.0,
#  'Live Chat - Free Video Talk': 14.0,
#  'Geeks Dating': 0.0,
#  'Live chat - free video chat': 1.0,
#  'House party - live chat': 1.0,
#  'Fishing Brain & Boating Maps Marine': 3.0,
#  'CAM5678 Video Chat': 0.0,
#  'Video chat live advices': 0.0,
#  'chat live chat': 24.0,
#  'Pet Lovers Dating': 0.0,
#  'Friend Find: free chat + flirt dating app': 23.0,
#  'Latin Dating': 0.0,
#  'Spine- The dating app': 5.0,
#  'Online Chat Girls Meet': 18.0,
#  'Wifi Mingle': 0.0,
#  'Girls Live Talk - Free Text and Video Chat': 6.0,
#  'Soy Luna - Top Music And Lyrics': 1.0,
#  'When Will You Get Married': 2.0,
#  'HOW TO ASK A GIRL OUT': 0.0,
#  'Online Girls Chat Group': 5.0,
#  'The DJ - Match with People': 0.0,
#  'Toronto Dating': 0.0,
#  'i miss you quotes and photos': 0.0,
#  'JoJo Siwa Top Hits Music': 0.0,
#  'UK Girls Mobile Numbers': 1.0,
#  'chat saudi arabia': 11.0,
#  'Chat Click - Dating Search': 4.0,
#  'Iraq love chat': 14.0,
#  'Healthy Relationships Guide': 0.0,
#  'following': 1.0,
#  'Gods by Night': 104.0,
#  'PlusOne': 0.0,
#  'Love Calendar - Couple Sharing Calendar & CoupleDay': 14.0,
#  'Speeding Joyride & Car Meet App': 3.0,
#  'LOBSTR - go on a lunch date': 101.0,
#  'Titanic App - Feminist Dating Application': 120.0,
#  'French Chat Room': 24.0,
#  'Soul Mate': 0.0,
#  'Diamond Engagement Rings': 0.0,
#  'Dating Tips For Men': 0.0,
#  'Halalguur': 6.0,
#  'Find Lover': 21.0,
#  '2Date Dating App, Love and matching': 41605.0,
#  'Teenage Chat & Dating': 5.0,
#  'Girls Online Talk - Free Text and Video Chat': 791.0,
#  'Online Girls Chat': 5323.0,
#  'LIVE VIDEO TALK': 478.0,
#  'SkyLove – Dating and chat': 69.0,
#  'Free Live Talk-Video Call': 158.0,
#  'FindLoving': 24.0,
#  'Sugar Daddies Dating App': 53.0,
#  'Chat Mexico: meet people, flirt and friendship': 8.0,
#  'Duolingo: Learn Languages Free': 6297590.0,
#  'TED': 181961.0,
#  'English Communication - Learn English for Chinese (Learn English for Chinese)': 2544.0,
#  'Khan Academy': 85375.0,
#  'Learn English with Wlingua': 314300.0,
#  'Ai La Trieu Phu - ALTP Free': 776.0,
#  'Princess Coloring Book': 9779.0,
#  'Learn Spanish - Español': 32346.0,
#  'English Grammar Test': 104676.0,
#  'Speed Reading': 10611.0,
#  'English for beginners': 9321.0,
#  'Flame - درب عقلك يوميا': 56065.0,
#  'Mermaids': 14286.0,
#  'Learn Japanese, Korean, Chinese Offline & Free': 133136.0,
#  'Kids Mode': 2469.0,
#  'PBS KIDS Video': 36214.0,
#  'Dinosaurs Coloring Pages': 390.0,
#  'Cars Coloring Pages': 1090.0,
#  'Babbel – Learn Languages': 267787.0,
#  'Math Tricks': 342918.0,
#  'Monster Truck Driver & Racing': 765.0,
#  'Learn English Words Free': 172640.0,
#  'Japanese / English one-shop search dictionary - Free Japanese - English - Japanese dictionary application': 61.0,
#  'English speaking texts': 1619.0,
#  'Thai Handwriting': 3168.0,
#  'THAI DICT 2018': 29855.0,
#  'Kanji test · Han search Kanji training (free version)': 6736.0,
#  "Game for KIDS: KIDS match'em": 7006.0,
#  'Flippy Campus - Buy & sell on campus at a discount': 889.0,
#  'Free intellectual training game application |': 5741.0,
#  'ABC Preschool Free': 27572.0,
#  'PINKFONG Baby Shark': 10852.0,
#  'English words application mikan': 9888.0,
#  'Learn English for beginners': 1929.0,
#  'Listen and learn English in seven days': 1516.0,
#  'Lumosity: #1 Brain Games & Cognitive Training App': 215301.0,
#  'Learn English from Persian: Persian to English': 423.0,
#  'English with Lingualeo': 254519.0,
#  'Learn languages, grammar & vocabulary with Memrise': 1107948.0,
#  'Quizlet: Learn Languages & Vocab with Flashcards': 211856.0,
#  'Udemy - Online Courses': 99020.0,
#  'Coursera: Online courses': 90481.0,
#  'edX - Online Courses by Harvard, MIT & more': 32380.0,
#  'Elevate - Brain Training Games': 248912.0,
#  'NeuroNation - Focus and Brain Training': 248555.0,
#  'Peak – Brain Games & Training': 272321.0,
#  'Memorado - Brain Games': 56897.0,
#  'Lynda - Online Training Videos': 8599.0,
#  'Brilliant': 41185.0,
#  'CppDroid - C/C++ IDE': 29978.0,
#  'Quiz&Learn Python': 304.0,
#  'C++ Tutorials': 358.0,
#  'C++ Programming': 11904.0,
#  'C Programming': 22248.0,
#  'Udacity - Lifelong Learning': 22384.0,
#  'Learn C++': 73404.0,
#  'Learn programming': 12733.0,
#  'Learn JavaScript': 25183.0,
#  'Learn Java': 52743.0,
#  'Learn HTML': 61749.0,
#  'Programming Hub, Learn to code': 55704.0,
#  'Learn SQL': 19277.0,
#  'Ready4 SAT (Prep4 SAT)': 13612.0,
#  'Socratic - Math Answers & Homework Help': 37862.0,
#  'Ready4 GMAT (Prep4 GMAT)': 18372.0,
#  'Pocket GMAT Math': 656.0,
#  'GMAT Question Bank': 240.0,
#  'GRE Tutor': 275.0,
#  'GRE Flashcards': 13791.0,
#  'play2prep: ACT, SAT prep': 3692.0,
#  'SAT Test': 2363.0,
#  'GMAT Math Flashcards': 1769.0,
#  'Pocket SAT Math': 430.0,
#  'TOEFL Prep & Practice from Magoosh': 756.0,
#  'GRE Prep & Practice by Magoosh': 3963.0,
#  'GRE® Flashcards by Kaplan': 316.0,
#  'SAT Vocabulary': 642.0,
#  'Magoosh GMAT Prep & Practice': 1058.0,
#  'SAT Flashcards: Prep & Vocabulary': 2277.0,
#  'Rosetta Stone: Learn to Speak & Read New Languages': 172508.0,
#  'Google Classroom': 69498.0,
#  'LinkedIn Learning: Online Courses to Learn Skills': 7973.0,
#  'Learn English with Phrases': 5695.0,
#  'Free english course': 142632.0,
#  'Learn 50 languages': 55256.0,
#  'Babbel – Learn Spanish': 54798.0,
#  'Mango Languages: Lovable Language Courses': 4815.0,
#  'Learn English with Aco': 75112.0,
#  'Learn to Speak English': 33646.0,
#  'busuu: Learn Languages - Spanish, English & More': 207294.0,
#  'My Class Schedule: Timetable': 9348.0,
#  'Study Checker': 3816.0,
#  'My Study Life - School Planner': 47847.0,
#  'HomeWork': 16195.0,
#  'Next Gen Science Standards': 206.0,
#  'myHomework Student Planner': 28392.0,
#  "Teacher's Gradebook - Additio": 3241.0,
#  'Common Core': 835.0,
#  'Homework Planner': 2525.0,
#  'TeachersPayTeachers': 828.0,
#  'Edmodo': 200214.0,
#  'Socrative Teacher': 1239.0,
#  'Training schedule - AllUniver': 702.0,
#  'Remind: School Communication': 108613.0,
#  'ClassDojo': 148536.0,
#  'Lerni. Learn languages.': 3847.0,
#  'HelloTalk — Chat, Speak & Learn Foreign Languages': 84311.0,
#  'Innovative: Learn 34 Languages': 14206.0,
#  'Chegg Study - Homework Help': 14700.0,
#  'Canvas Student': 42828.0,
#  'Timetable': 40209.0,
#  'EasyBib: Citation Generator': 1405.0,
#  'SoloLearn: Learn to Code for Free': 256079.0,
#  'Kids Learn Languages by Mondly': 2078.0,
#  'Blinkist - Nonfiction Books': 16103.0,
#  'Sago Mini Hat Maker': 11.0,
#  'Fuzzy Numbers: Pre-K Number Foundation': 21.0,
#  'Toca Life: City': 31100.0,
#  'Toca Life: Hospital': 3528.0,
#  'Netflix': 5453997.0,
#  'Complete Spanish Movies': 11656.0,
#  'Pluto TV - It’s Free TV': 28948.0,
#  'Tubi TV - Free Movies & TV': 296771.0,
#  'YouTube Kids': 469851.0,
#  'Mobile TV': 10939.0,
#  'TV+': 98509.0,
#  'Digital TV': 5241.0,
#  'Motorola Spotlight Player™': 22508.0,
#  'Vigo Lite': 10291.0,
#  'Google Play Games': 7168735.0,
#  'Hotstar': 4885646.0,
#  'Peers.TV: broadcast TV channels First, Match TV, TNT ...': 141980.0,
#  'The green alien dance': 6979.0,
#  'Spectrum TV': 46618.0,
#  'H TV': 103064.0,
#  'StarTimes - Live International Champions Cup': 17682.0,
#  'Cinematic Cinematic': 37000.0,
#  'MEGOGO - Cinema and TV': 175528.0,
#  'Talking Angela': 1828284.0,
#  'DStv Now': 34923.0,
#  'ivi - movies and TV shows in HD': 684116.0,
#  'Radio Javan': 46916.0,
#  'Viki: Asian TV Dramas & Movies': 407719.0,
#  'Talking Ginger 2': 702975.0,
#  'Girly Lock Screen Wallpaper with Quotes': 32458.0,
#  'No.Draw - Colors by Number 2018': 235906.0,
#  '🔥 Football Wallpapers 4K | Full HD Backgrounds 😍': 11661.0,
#  'Movies by Flixster, with Rotten Tomatoes': 653008.0,
#  'Low Poly – Puzzle art game': 23063.0,
#  'BBC Media Player': 87384.0,
#  'Amazon Prime Video': 411683.0,
#  'Adult Glitter Color by Number Book - Sandbox Pages': 8918.0,
#  'IMDb Movies & TV': 501498.0,
#  'Twitch: Livestream Multiplayer Games & Esports': 2133047.0,
#  'Ziggo GO': 29690.0,
#  'YouTube Gaming': 130549.0,
#  'PlayStation App': 613059.0,
#  'Talking Ben the Dog': 1633565.0,
#  'Red Bull TV: Live Sports, Music & Entertainment': 42069.0,
#  'Trailer Addict Movie Trailers': 2646.0,
#  'Cinemark Theatres': 21867.0,
#  'Regal Cinemas': 32732.0,
#  'Fandango Movies - Times + Tickets': 243747.0,
#  'Marcus Theatres': 2639.0,
#  'Harkins Theatres': 1511.0,
#  'AMC Theatres': 44550.0,
#  'Food Network': 7823.0,
#  'Cooking Channel': 1033.0,
#  'Animal Planet GO': 2442.0,
#  'VRV: Anime, game videos & more': 15254.0,
#  'DramaFever: Stream Asian Drama Shows & Movies': 155234.0,
#  'Crunchyroll - Everything Anime': 310066.0,
#  'Investigation Discovery GO': 12216.0,
#  'Crackle - Free TV & Movies': 388089.0,
#  'CBS - Full Episodes & Live TV': 92058.0,
#  'STARZ': 88185.0,
#  'Acorn TV: World-class TV from Britain and Beyond': 493.0,
#  'HISTORY: Watch TV Show Full Episodes & Specials': 33387.0,
#  'Nick': 123309.0,
#  'VH1': 27424.0,
#  'FOX NOW - On Demand & Live TV': 60841.0,
#  'A&E - Watch Full Episodes of TV Shows': 29708.0,
#  'The CW': 288209.0,
#  'BET NOW - Watch Shows': 14807.0,
#  'Hulu: Stream TV, Movies & more': 319777.0,
#  'HBO NOW: Stream TV & Movies': 61230.0,
#  'Univision NOW - Live TV and On Demand': 22997.0,
#  'SHOWTIME': 12398.0,
#  'Lifetime - Watch Full Episodes & Original Movies': 35931.0,
#  'SeriesGuide – Show & Movie Manager': 64448.0,
#  'Comedy Central': 22378.0,
#  'CW Seed': 16391.0,
#  'The NBC App - Watch Live TV and Full Episodes': 58104.0,
#  'WWE': 736824.0,
#  'Universal Kids': 1968.0,
#  'MTV': 35279.0,
#  'LEGO® TV': 17250.0,
#  'HBO GO: Stream with TV Package': 87734.0,
#  'Showtime Anytime': 18522.0,
#  'PlayKids - Educational cartoons and games for kids': 182173.0,
#  'FOX': 197774.0,
#  'Telemundo Now': 8674.0,
#  'Vudu Movies & TV': 58082.0,
#  'Yidio: TV Show & Movie Guide': 27424.0,
#  'Redbox': 115033.0,
#  'Tribeca Shortlist - Handpicked Movies': 801.0,
#  'Nick Jr. - Shows & Games': 8968.0,
#  'Sticker Market: Emoji keyboard': 303.0,
#  'Kidjo TV Kids Have Fun & Learn': 732.0,
#  'Laugh Out Loud by Kevin Hart': 1856.0,
#  'ColorFul - Adult Coloring Book': 50725.0,
#  'Hamilton — The Official App': 1575.0,
#  'My Talking Pet': 6238.0,
#  'Funny Pics': 9941.0,
#  'Funny Quotes Free': 23666.0,
#  'LOL Pics (Funny Pictures)': 67554.0,
#  'Meme Creator': 38769.0,
#  'Imgur: Find funny GIFs, memes & watch viral videos': 160164.0,
#  'Meme Generator': 3771.0,
#  'SketchBook - draw and paint': 256664.0,
#  'Colorfy: Coloring Book for Adults - Free': 787107.0,
#  'All Events in City': 3782.0,
#  'Ticketmaster Event Tickets': 40113.0,
#  'Reminder': 7074.0,
#  'Birdays - Birthday reminder': 2153.0,
#  'StubHub - Tickets to Sports, Concerts & Events': 26089.0,
#  'Fever': 20611.0,
#  'DroidAdmin for Android - Advice': 811.0,
#  'SeatGeek – Tickets to Sports, Concerts, Broadway': 15558.0,
#  'my4D': 573.0,
#  'VAN NIAN 2018 - Vietnamese Calendar': 37.0,
#  'Vivid Seats – Event Tickets': 8232.0,
#  'Name days': 3089.0,
#  'LBB - Find New & Unique Things To Do Around You': 3874.0,
#  'Happy Birthday Songs Offline': 464.0,
#  'Series Valley of the Wolves full of part': 731.0,
#  'Mummatikabalkuragi': 69.0,
#  'Gametime - Tickets to Sports, Concerts, Theater': 8800.0,
#  'PTI Flex Maker, Photo Frame Editor & Songs 2018': 99.0,
#  'Wipe out': 30.0,
#  'Birthdays & Other Events': 456.0,
#  'Sarajevo Film Festival - Official': 6.0,
#  'Summer Madness': 4.0,
#  'Events High - Meet Your City!': 3200.0,
#  'vide-greniers.org': 5839.0,
#  'SUMMER SONIC app': 4.0,
#  'Quake & Volcanoes: 3D Globe of Volcanic Eruptions': 663.0,
#  'Prosperity': 16.0,
#  "Picktrainer: India's largest photo contest app": 1065.0,
#  'AAS-IN-ASIA 2018': 3.0,
#  'Moot Peru 2018': 13.0,
#  'FM News': 46.0,
#  'Goldstar: Live Event Tickets': 1953.0,
#  'Emmabodafestivalen': 12.0,
#  'KudaGo - things to do in NY': 4298.0,
#  'Mindvalley U Tallinn 2018': 1.0,
#  'Rockmaraton Info': 49.0,
#  'Freitas Auctioneer Official': 100.0,
#  'mobLee Events': 11.0,
#  'Xceed - Clubs, DJs, Festivals & Tickets': 399.0,
#  'AMM Events & CPD': 5.0,
#  'Arab Halls - For Wedding & Events': 28.0,
#  'MeAuDote - An act of love that saves a life': 250.0,
#  'TCF National Conference': 1.0,
#  'Endurance Lifestyle': 7.0,
#  'K PLUS': 124324.0,
#  'ING Banking': 39041.0,
#  'Citibanamex Movil': 52306.0,
#  'The postal bank': 36718.0,
#  'KTB Netbank': 42644.0,
#  'Mobile Bancomer': 278082.0,
#  'Nedbank Money': 6076.0,
#  'SCB EASY': 112656.0,
#  'CASHIER': 335738.0,
#  'Rabo Banking': 31906.0,
#  'Capitec Remote Banking': 20672.0,
#  'Itau bank': 957973.0,
#  'Nubank': 130582.0,
#  'The Societe Generale App': 31218.0,
#  'IKO': 167168.0,
#  'Cash App': 34428.0,
#  'Standard Bank / Stanbic Bank': 15247.0,
#  'Bualuang mBanking': 48445.0,
#  'Intesa Sanpaolo Mobile': 35518.0,
#  'UBA Mobile Banking': 12185.0,
#  'BBVA Spain': 36746.0,
#  'MyMo by GSB': 21996.0,
#  'VTB-Online': 138371.0,
#  'Ecobank Mobile Banking': 12073.0,
#  'Banorte Movil': 111632.0,
#  'Wells Fargo Mobile': 250719.0,
#  'Credit Karma': 706618.0,
#  'BZWBK24 mobile': 64983.0,
#  'PayPal': 659760.0,
#  'Capital One® Mobile': 510401.0,
#  'Zenith Bank Mobile App': 7215.0,
#  'GCash - Buy Load, Pay Bills, Send Money': 25508.0,
#  'Post Bank': 60449.0,
#  'İşCep': 381788.0,
#  "People's Bank": 10697.0,
#  'Google Pay': 348132.0,
#  'Transfer': 31804.0,
#  'T-Mobile in': 3856.0,
#  'TrueMoney Wallet': 199684.0,
#  'Alfa-Bank (Alfa-Bank)': 44545.0,
#  'Bank of Brazil': 1336246.0,
#  'WiseBanyan - Invest For Free': 257.0,
#  'Robinhood - Investing, No Fees': 57493.0,
#  'Wells Fargo Daily Change': 283.0,
#  'Even - organize your money, get paid early': 12304.0,
#  'Digit Save Money Automatically': 8188.0,
#  'Stash: Invest. Learn. Save.': 11919.0,
#  'Acorns - Invest Spare Change': 45962.0,
#  'Money Lover: Expense Tracker, Budget Planner': 126447.0,
#  'Expense IQ Money Manager': 21570.0,
#  'Money Manager Expense & Budget': 134564.0,
#  'Prism Pay Bills, Track Money, Personal Finance': 16961.0,
#  'Monefy - Money Manager': 111254.0,
#  'Simple - Better Banking': 7731.0,
#  'Chime - Mobile Banking': 5928.0,
#  'Bluebird by American Express': 15703.0,
#  'Walmart MoneyCard': 6148.0,
#  'Moven - Smart Finances': 861.0,
#  'Qapital - Save Small. Live Large': 8662.0,
#  'Experian - Free Credit Report': 23130.0,
#  'Branch': 69973.0,
#  'WalletHub - Free Credit Score, Report & Monitoring': 1311.0,
#  'CreditWise from Capital One': 26587.0,
#  'NerdWallet: Personal Finance, Credit Score & Cash': 2417.0,
#  'my face': 1054.0,
#  'Credit Sesame': 25166.0,
#  'Mint: Budget, Bills, Finance': 129305.0,
#  'Fresh EBT - Food Stamp Balance': 19870.0,
#  'Hurdlr: Track Mileage, Expenses, and Log Receipts': 3596.0,
#  'Mobills: Budget Planner': 161440.0,
#  'Everlance: Free Mileage Log': 7514.0,
#  'MileIQ - Free Mileage Tracker for Business': 46106.0,
#  'QuickBooks Self-Employed:Mileage Tracker and Taxes': 15141.0,
#  'FREE Stock Market Trading Tips': 714.0,
#  'MetaTrader 5': 42410.0,
#  'MetaTrader 4': 260547.0,
#  'Stock Quote': 4344.0,
#  'Seeking Alpha': 22808.0,
#  'Stock Trainer: Virtual Trading (Stock Markets)': 42809.0,
#  'Stocks: Realtime Quotes Charts': 16808.0,
#  'Stocks, Forex, Bitcoin, Ethereum: Portfolio & News': 157505.0,
#  'CNBC: Breaking Business News & Live Market Data': 24666.0,
#  'US Stock Market': 1922.0,
#  'Bloomberg Professional': 3334.0,
#  'E*TRADE Mobile': 10657.0,
#  'MSN Money- Stock Quotes & News': 78361.0,
#  'Fox Business': 2594.0,
#  'NSE Mobile Trading': 13868.0,
#  'Yahoo Finance': 135952.0,
#  'JStock - Stock Market, Portfolio & News': 11066.0,
#  'Webull - Stock Quotes & Free Stock Trading': 34861.0,
#  'Trading 212 - Forex, Stocks, CFDs': 37580.0,
#  'Moneycontrol – Stocks, Sensex, Mutual Funds, IPO': 281635.0,
#  'Current debit card and app made for teens': 685.0,
#  'Betterment': 3780.0,
#  'Citizens Bank Mobile Banking': 15192.0,
#  'GoBank': 5950.0,
#  'NetSpend Prepaid': 15993.0,
#  'BBVA Compass Banking': 5905.0,
#  'BankMobile Vibe App': 14627.0,
#  'Netspend Skylight ONE': 1098.0,
#  'ACE Elite': 2898.0,
#  'U.S. Bank': 70782.0,
#  'Huntington Mobile': 11264.0,
#  'USAA Mobile': 100997.0,
#  'Associated Credit Union Mobile': 3290.0,
#  'Bank of America Mobile Banking': 341090.0,
#  'USE Credit Union Mobile': 964.0,
#  'Discover Mobile': 87951.0,
#  'Amex Mobile': 24729.0,
#  'Citi Mobile®': 78306.0,
#  'Navy Federal Credit Union': 43313.0,
#  'Chase Mobile': 1374549.0,
#  'HDFC Bank MobileBanking': 208463.0,
#  'Barclays US for Android': 6998.0,
#  "McDonald's": 145646.0,
#  'Easy and Fast Recipes': 95.0,
#  'Cookpad - FREE recipe search makes fun cooking · musical making!': 64784.0,
#  'DELISH KITCHEN - FREE recipe movies make food fun and easy!': 32997.0,
#  'Sumine side dish - dish recipe side dish': 82.0,
#  'Easy Recipes': 2707.0,
#  'Delicious Recipes': 129737.0,
#  'Tastely': 611136.0,
#  'Pastry & Cooking (Without Net)': 6118.0,
#  'Frigo Magic: Easy recipe idea and anti-waste': 2473.0,
#  "McDonald's - McDonald's Japan": 109784.0,
#  'Debonairs Pizza': 3320.0,
#  'Popeyes® App': 61.0,
#  "Dunkin' Donuts": 68270.0,
#  'Pyaterochka': 8412.0,
#  'Refreshing app Free application that can use deal coupons': 10741.0,
#  'Simple Recipes': 3803.0,
#  'Grubhub: Food Delivery': 155944.0,
#  'Panera Bread': 10225.0,
#  'Chick-fil-A': 27931.0,
#  'hellofood - Food Delivery': 43614.0,
#  'Starbucks': 455496.0,
#  'Easy and quick desserts': 1398.0,
#  "Domino's Pizza USA": 1032935.0,
#  'Chef - Recipes & Cooking': 32405.0,
#  'Delivery Club-food delivery: pizza, sushi, burger, salad': 151080.0,
#  'HungerStation': 22513.0,
#  'Delivery yogi.': 90042.0,
#  'Delivery trough - delivery trough delivery trough': 58316.0,
#  'Dr. Oetker recipe ideas': 8509.0,
#  'SONIC Drive-In': 19373.0,
#  'SUBWAY®': 21381.0,
#  'GialloZafferano: Recipes': 30224.0,
#  'Dairy Queen': 742.0,
#  '9th stage': 454.0,
#  'OpenRice': 14952.0,
#  'SarashpazPapion (Cooking with Chef Bowls)': 1250.0,
#  'Little Caesars': 1726.0,
#  'Recipes Pastries and homemade pies More than 500 recipes for pastries': 14065.0,
#  'Om Waleed Sweets': 556.0,
#  'Eat Fast Prepare "Without Internet"': 4925.0,
#  'Wendy’s – Food and Offers': 6512.0,
#  'My Recipes Cookbook : RecetteTek': 11707.0,
#  'Healthy Recipes Free': 1077.0,
#  'Cookbook Recipes': 46539.0,
#  'ChefTap Recipes & Grocery List': 9066.0,
#  'Recipe Keeper': 1962.0,
#  'My CookBook (Recipe Manager)': 22071.0,
#  ...}

# %% [markdown]
# Using our dictionary reviews_max, (which contains `name` and `reviews` of each app or "row"), lets capture the full row to a new dataset.
#
# The dictionary reviews_max will help us to match the 'right duplicate' from original dataset. By 'right duplicate' we mean the duplicate with the highest number of reviews.
#
# We will take that best match along with its complete row to our new dataset called **android_clean**

# %%
android_clean = [] # Stores our new cleaned dataset
already_added = [] # keeps record to help where we have more than one maximum reviews for an app

for row in android: 
    name = row[0]
    n_reviews = float(row[3])
    if (reviews_max[name] == n_reviews) and (name not in already_added): # If n_reviews is the same as the number of maximum reviews of the app name in review_max and name is not already in the list already_added
        android_clean.append(row) # build the new dataset
        already_added.append(name) # to assist in cases where we have same number of reviews for more than one entry
print(len(android_clean))
print('\n')
explore_data(android_clean,0,10)
# Out:
# 9659
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']
#
#
# ['Smoke Effect Photo Maker - Smoke Editor', 'ART_AND_DESIGN', '3.8', '178', '19M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'April 26, 2018', '1.1', '4.0.3 and up']
#
#
# ['Infinite Painter', 'ART_AND_DESIGN', '4.1', '36815', '29M', '1,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'June 14, 2018', '6.1.61.1', '4.2 and up']
#
#
# ['Garden Coloring Book', 'ART_AND_DESIGN', '4.4', '13791', '33M', '1,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'September 20, 2017', '2.9.2', '3.0 and up']
#
#
# ['Kids Paint Free - Drawing Fun', 'ART_AND_DESIGN', '4.7', '121', '3.1M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'July 3, 2018', '2.8', '4.0.3 and up']
#
#
# ['Text on Photo - Fonteee', 'ART_AND_DESIGN', '4.4', '13880', '28M', '1,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'October 27, 2017', '1.0.4', '4.1 and up']

# %%
# Lets do the same for AppStore data
duplicate_entries = []
unique_entries = []

for row in apple:
    if row[0] in unique_entries:
        duplicate_entries.append(row[0])
    else :
        unique_entries.append(row[0])
        
print('Number of unique apps: ' ,len(unique_entries))
print('Number of duplicate apps: ' , len(duplicate_entries))
print('\n')
print('Examples of duplicate apps:', duplicate_entries[:15])
# Out:
# Number of unique apps:  7197
# Number of duplicate apps:  0
#
#
# Examples of duplicate apps: []

# %% [markdown]
# - There are no Duplicate entries in AppStore dataset. So no special treatments required

# %% [markdown]
# ### Removing Non-English Apps

# %% [markdown]
# <font color='red'>The numbers corresponding to the characters we commonly use in an English text are all in the range 0 to 127, according to the ASCII (American Standard Code for Information Interchange) system. Based on this number range, we can build a function that detects whether a character belongs to the set of common English characters or not. If the number is equal to or less than 127, then the character belongs to the set of common English characters.
#
# If an app name contains a character that is greater than 127, then it probably means that the app has a non-English name.

# %%
def is_english(string):
    '''
    Tells whether a character belongs to standard english or not
    
    Args:
        string: String
        
    Returns:
        bool
    '''
    for element in string:
        if ord(element) > 127:
            return False
        return True # Else is implied

# %% [markdown]
# Lets check whether the function works correctly or not:

# %%
print(is_english('Instagram'))
print(is_english('爱奇艺PPS -《欢乐颂2》电视剧热播'))
print(is_english('Docs To Go™ Free Office Suite'))
print(is_english('Instachat 😜'))
# Out:
# True
# False
# True
# True

# %% [markdown]
# The function worked correctly but, If we're going to use the function we've created, we'll lose useful data since many English apps will be incorrectly labeled as non-English. This is because emojis and characters like ™ fall outside the ASCII range and have corresponding numbers over 127, the emojis and characters that the function picked out

# %% [markdown]
# Lets change the function to make it a bit more lenient

# %%
def is_english(string):
    '''
    Lenient version of is_english() as It allows some non-ascii characters.
    
    Args
        string: String
        
    Returns
        bool
    '''
    non_ascii = 0
    for element in string:
        if ord(element) > 127:
            non_ascii += 1
    if non_ascii > 3: # Allowing 3 non-ASCII characters
        return False
    else:
        return True

# %% [markdown]
# Lets test the newer version of the function we just made

# %%
print(is_english('Docs To Go™ Free Office Suite'))
print(is_english('Instachat 😜'))
print(is_english("爱奇艺PPS -《欢乐颂2》电视剧热播"))
# Out:
# True
# True
# False

# %% [markdown]
# - This worked much better. By relaxing the condition, we are able to save some data we could had lost

# %% [markdown]
# Next, we are going to apply the above function our datasets to remove any apps which include non-English characters.

# %%
english_android = []
english_apple = []

for app in android_clean:
    name = app[0] # index of the name of an App
    if is_english(name):
        english_android.append(app)
        
for app in apple:
    name = app[1] # index of the name of an App
    if is_english(name):
        english_apple.append(app)
        
print('After applying the `is_english()` function, we are left with:\n {} PlayStore apps\n'.format(len(english_android)))   
print('\n')
print('After applying the `is_english()` function, we are left with:\n {} AppStore apps\n'.format(len(english_apple)))
# Out:
# After applying the `is_english()` function, we are left with:
#  9614 PlayStore apps
#
#
#
# After applying the `is_english()` function, we are left with:
#  6183 AppStore apps

# %% [markdown]
# ### Isolating Free English apps

# %% [markdown]
# As we mentioned in the introduction, we only build apps that are free to download and install, and our main source of revenue consists of in-app ads. Our data sets contain both free and non-free apps; we'll need to isolate only the free apps for our analysis.

# %%
free_english_android = []
free_english_apple = []

for row in english_android:
    name = row[0] # Index of name within the row
    price = row[6] # Index of the price within the row
    
    if price == 'Free': # 'Free' marks $ 0.0 in this dataset
        free_english_android.append(row)


for row in english_apple:
    name = row[1]
    price = row[4]
    
    if price == '0.0': # '0.0' marks $ 0.0 in the dataset
        free_english_apple.append(row) 

print('Android apps those are in english and are free:\n', len(free_english_android))
print('\n')
print('Apple apps those are in english and are free:\n', len(free_english_apple))
# Out:
# Android apps those are in english and are free:
#  8863
#
#
# Apple apps those are in english and are free:
#  3222

# %% [markdown]
# ---

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# Because our end goal is to add the app on both Google Play and the App Store, we need to find app profiles that are successful on both markets.
#
# Let's begin the analysis by getting a sense of what are the **most common genres** for each market. For this, we'll need to build frequency tables for a few columns in our data sets.
#
# For Genres we have two columns in PlayStore Data, namely `Genres` and `Categories`, whereas in AppStore Data we just have one column `prime_genre`.

# %% [markdown]
# Do dig deeper into them, lets build two functions to analyze the frequencies:
#
# - freq_tables to generate frequency tables that show percentages
# - display_table to display the percentages in an order

# %%
def freq_table(dataset, index):
    '''
    Generates frequency tables
    
    Args:
        dataset: Dataset
        index: Index of the column frequencies are to be drawn from
        
    Return:
        Frequencies as Percentages
    '''
    freq_apps = {}
    total = 0 
    
    for row in dataset:
        total += 1
        val = row[index]
        if val in freq_apps:
            freq_apps[val] += 1
        else:
            freq_apps[val] = 1
    
    #Converting frquencies to percentage table
    table_percentages = {}
    for key in freq_apps:
        percentage = (freq_apps[key] / total) * 100
        table_percentages[key] = percentage 
    
    return table_percentages

# %%
def display_table(dataset, index):
    '''
    Sorts the frequency table 
    
    Args:
        dataset: Dataset
        index: Index of the column frequencies are to be drawn from
        
    Return:
        Prints the entries of the frequency table in descending order
    '''
    table = freq_table(dataset, index) # takes in the table generated from `freq_table()`
    table_display = [] # initiate a list
    for key in table:
        key_val_as_tuple = (table[key], key) # transformation into tupples, Dictionaries can not be ordered
        table_display.append(key_val_as_tuple) # append into the list

    table_sorted = sorted(table_display, reverse = True) # sorts the list in a descending order
    for entry in table_sorted:
        print(entry[1], ':', entry[0]) # print the list

# %% [markdown]
# Lets check both functions on our datasets

# %%
# To make sure we get correct Index numbers, Lets print our headers we extracted in the beginning of this project
print('Android Header:\n',android_header,'\n\n','Apple Header:\n',apple_header)
# Out:
# Android Header:
#  ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#  Apple Header:
#  ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']

# %% [markdown]
# **Free English AppStore Apps:**

# %% [markdown]
# Examining the frequency table for the `prime_genre` column of the AppStore data set.

# %%
display_table(free_english_apple, -5) # Index -5: `prime_genre`
# Out:
# Games : 58.16263190564867
# Entertainment : 7.883302296710118
# Photo & Video : 4.9658597144630665
# Education : 3.662321539416512
# Social Networking : 3.2898820608317814
# Shopping : 2.60707635009311
# Utilities : 2.5139664804469275
# Sports : 2.1415270018621975
# Music : 2.0484171322160147
# Health & Fitness : 2.0173805090006205
# Productivity : 1.7380509000620732
# Lifestyle : 1.5828677839851024
# News : 1.3345747982619491
# Travel : 1.2414649286157666
# Finance : 1.1173184357541899
# Weather : 0.8690254500310366
# Food & Drink : 0.8069522036002483
# Reference : 0.5586592178770949
# Business : 0.5276225946617008
# Book : 0.4345127250155183
# Navigation : 0.186219739292365
# Medical : 0.186219739292365
# Catalogs : 0.12414649286157665

# %% [markdown]
# **Free English PlayStore Apps:**

# %% [markdown]
# Examining the frequency table for the `Genres` column of the PlayStore data set.

# %%
display_table(free_english_android, 9) # Index 9: `Genres`
# Out:
# Tools : 8.450863138892023
# Entertainment : 6.070179397495204
# Education : 5.348076272142616
# Business : 4.580841701455489
# Productivity : 3.8925871601038025
# Lifestyle : 3.8925871601038025
# Finance : 3.7007785174320205
# Medical : 3.542818458761142
# Sports : 3.463838429425702
# Personalization : 3.317161232088458
# Communication : 3.2494640640866526
# Action : 3.102786866749408
# Health & Fitness : 3.068938282748505
# Photography : 2.944826808078529
# News & Magazines : 2.798149610741284
# Social : 2.6627552747376737
# Travel & Local : 2.324269434728647
# Shopping : 2.245289405393208
# Books & Reference : 2.1437436533904997
# Simulation : 2.042197901387792
# Dating : 1.8616721200496444
# Arcade : 1.8616721200496444
# Video Players & Editors : 1.7826920907142052
# Casual : 1.7488435067133026
# Maps & Navigation : 1.399074805370642
# Food & Drink : 1.241114746699763
# Puzzle : 1.128286133363421
# Racing : 0.9928917973598104
# Role Playing : 0.9364774906916393
# Libraries & Demo : 0.9364774906916393
# Auto & Vehicles : 0.9251946293580051
# Strategy : 0.9026289066907368
# House & Home : 0.8236488773552973
# Weather : 0.8010831546880289
# Events : 0.7108202640189552
# Adventure : 0.6769716800180525
# Comics : 0.6092745120162473
# Beauty : 0.5979916506826132
# Art & Design : 0.5979916506826132
# Parenting : 0.4964458986799052
# Card : 0.4400315920117342
# Casino : 0.42874873067809993
# Trivia : 0.4174658693444658
# Educational;Education : 0.3949001466771973
# Board : 0.38361728534356315
# Educational : 0.37233442400992894
# Education;Education : 0.33848584000902626
# Word : 0.25950581067358686
# Casual;Pretend Play : 0.2369400880063184
# Music : 0.20309150400541578
# Racing;Action & Adventure : 0.16924292000451313
# Puzzle;Brain Games : 0.16924292000451313
# Entertainment;Music & Video : 0.16924292000451313
# Casual;Brain Games : 0.1353943360036105
# Casual;Action & Adventure : 0.1353943360036105
# Arcade;Action & Adventure : 0.1241114746699763
# Action;Action & Adventure : 0.10154575200270789
# Educational;Pretend Play : 0.09026289066907367
# Simulation;Action & Adventure : 0.07898002933543948
# Parenting;Education : 0.07898002933543948
# Entertainment;Brain Games : 0.07898002933543948
# Board;Brain Games : 0.07898002933543948
# Parenting;Music & Video : 0.06769716800180525
# Educational;Brain Games : 0.06769716800180525
# Casual;Creativity : 0.06769716800180525
# Art & Design;Creativity : 0.06769716800180525
# Education;Pretend Play : 0.05641430666817105
# Role Playing;Pretend Play : 0.045131445334536835
# Education;Creativity : 0.045131445334536835
# Role Playing;Action & Adventure : 0.033848584000902626
# Puzzle;Action & Adventure : 0.033848584000902626
# Entertainment;Creativity : 0.033848584000902626
# Entertainment;Action & Adventure : 0.033848584000902626
# Educational;Creativity : 0.033848584000902626
# Educational;Action & Adventure : 0.033848584000902626
# Education;Music & Video : 0.033848584000902626
# Education;Brain Games : 0.033848584000902626
# Education;Action & Adventure : 0.033848584000902626
# Adventure;Action & Adventure : 0.033848584000902626
# Video Players & Editors;Music & Video : 0.022565722667268417
# Sports;Action & Adventure : 0.022565722667268417
# Simulation;Pretend Play : 0.022565722667268417
# Puzzle;Creativity : 0.022565722667268417
# Music;Music & Video : 0.022565722667268417
# Entertainment;Pretend Play : 0.022565722667268417
# Casual;Education : 0.022565722667268417
# Board;Action & Adventure : 0.022565722667268417
# Trivia;Education : 0.011282861333634209
# Travel & Local;Action & Adventure : 0.011282861333634209
# Tools;Education : 0.011282861333634209
# Strategy;Education : 0.011282861333634209
# Strategy;Creativity : 0.011282861333634209
# Strategy;Action & Adventure : 0.011282861333634209
# Simulation;Education : 0.011282861333634209
# Role Playing;Brain Games : 0.011282861333634209
# Racing;Pretend Play : 0.011282861333634209
# Puzzle;Education : 0.011282861333634209
# Parenting;Brain Games : 0.011282861333634209
# Music & Audio;Music & Video : 0.011282861333634209
# Lifestyle;Pretend Play : 0.011282861333634209
# Lifestyle;Education : 0.011282861333634209
# Health & Fitness;Education : 0.011282861333634209
# Health & Fitness;Action & Adventure : 0.011282861333634209
# Entertainment;Education : 0.011282861333634209
# Communication;Creativity : 0.011282861333634209
# Comics;Creativity : 0.011282861333634209
# Casual;Music & Video : 0.011282861333634209
# Card;Brain Games : 0.011282861333634209
# Card;Action & Adventure : 0.011282861333634209
# Books & Reference;Education : 0.011282861333634209
# Art & Design;Pretend Play : 0.011282861333634209
# Art & Design;Action & Adventure : 0.011282861333634209
# Arcade;Pretend Play : 0.011282861333634209
# Adventure;Education : 0.011282861333634209

# %% [markdown]
# Examining the frequency table for the `Category` column of the PlayStore data set.

# %%
display_table(free_english_android, 1)
# Out:
# FAMILY : 19.21471285117906
# GAME : 9.511452104253639
# TOOLS : 8.462146000225657
# BUSINESS : 4.580841701455489
# LIFESTYLE : 3.9038700214374367
# PRODUCTIVITY : 3.8925871601038025
# FINANCE : 3.7007785174320205
# MEDICAL : 3.542818458761142
# SPORTS : 3.4187069840911652
# PERSONALIZATION : 3.317161232088458
# COMMUNICATION : 3.2494640640866526
# HEALTH_AND_FITNESS : 3.068938282748505
# PHOTOGRAPHY : 2.944826808078529
# NEWS_AND_MAGAZINES : 2.798149610741284
# SOCIAL : 2.6627552747376737
# TRAVEL_AND_LOCAL : 2.335552296062281
# SHOPPING : 2.245289405393208
# BOOKS_AND_REFERENCE : 2.1437436533904997
# DATING : 1.8616721200496444
# VIDEO_PLAYERS : 1.7826920907142052
# MAPS_AND_NAVIGATION : 1.399074805370642
# FOOD_AND_DRINK : 1.241114746699763
# EDUCATION : 1.128286133363421
# LIBRARIES_AND_DEMO : 0.9364774906916393
# AUTO_AND_VEHICLES : 0.9251946293580051
# ENTERTAINMENT : 0.8800631840234684
# HOUSE_AND_HOME : 0.8236488773552973
# WEATHER : 0.8010831546880289
# EVENTS : 0.7108202640189552
# PARENTING : 0.6544059573507841
# ART_AND_DESIGN : 0.6431230960171499
# COMICS : 0.6205573733498815
# BEAUTY : 0.5979916506826132

# %%
# AppStore's Data does not have a Category

# %% [markdown]
# ##### Unlike PlayStore's data, AppStore's Data does not have a column of Categories.
#
# The difference between Genres and the Category column is not clear. However, Category column gives a better insight for 'Bird's eye' review. It has clearer defined groups than Genre column. Furthermore, it seems to run parallel with the Genre column of `prime genre` of AppStore. We might need Genre column when we reach the deeper level. For now, lets use Category column

# %% [markdown]
# - In Free English Apps,
#     - Apple's AppStore has more number of users looking for fun Apps,
#         - Top three genres namely *Games*, *Entertainment* and *Photos & Videos* account for well above 70% of apps
#         - *Games*, being alone, accounts for 58% of the apps
#
#     - Google's PlayStore has a more balanced user base with equal emphasis for everything.
#         - *Family*, *Games*, *Tools*, and *Business* score approximately 20%, 10%, 9%, and 5% respectively

# %% [markdown]
# ## Most Popular Free English Apps by Genre

# %% [markdown]
# One way to find out what genres are the most popular (have the most users) is to calculate the average number of installs for each app genre.
# - For the Google Play data set, we can find this information in the `Installs` column.
# - For the App Store data set this information is missing. As a workaround, we'll take the total number of user ratings as a proxy, which we can find in the `rating_count_tot` app.

# %% [markdown]
# #### on Apple's App Store

# %%
genres_apple = freq_table(free_english_apple, -5)
genres_table = []
count = 0

for genre in genres_apple:
    total = 0
    len_genre = 0
    
    for row in free_english_apple:
        genre_app = row[-5]
        
        if genre_app == genre:            
            n_ratings = float(row[5])
            total += n_ratings
            len_genre += 1
            
    avg_n_ratings = total / len_genre
    key_val_tuple = (avg_n_ratings, genre)
    genres_table.append(key_val_tuple)
    count += avg_n_ratings
    
sorted_table = sorted(genres_table, reverse = True)

for element in sorted_table:
    print(element[1], ':', round(element[0]))
# Out:
# Navigation : 86090
# Reference : 74942
# Social Networking : 71548
# Music : 57327
# Weather : 52280
# Book : 39758
# Food & Drink : 33334
# Finance : 31468
# Photo & Video : 28442
# Travel : 28244
# Shopping : 26920
# Health & Fitness : 23298
# Sports : 23009
# Games : 22789
# News : 21248
# Productivity : 21028
# Utilities : 18684
# Lifestyle : 16486
# Entertainment : 14030
# Business : 7491
# Education : 7004
# Catalogs : 4004
# Medical : 612

# %% [markdown]
# **Observations**
#
# **Apprently**, the following are top 5 and bottom 5 Genres of **Free English Apps** on **AppStore**
#
# The top 5 Genres in Free English apps of Apple's AppStore are
# 1. Navigation
# 2. Reference
# 3. Social Networking
# 4. Music
# 5. Weather
#
# Least Popular Genres in Free English apps of Apple's AppStore are (Lowest first)
# 1. Medical
# 2. Catalogs
# 3. Education
# 4. Business
# 5. Entertainment
#
# **Inference**
# - We can not move on with these results to make recommendation without exploring the influences on these results and probing its meanings. For that, lets do a quick exploration of the top 5 genres

# %%
apparently_popular_genres_ios = ['Navigation', 'Reference', 'Social Networking', 'Music', 'Weather']

for genre in apparently_popular_genres_ios: # loops for each term in the list
    print('\n','----',genre,'----','\n') # prints a header
    for row in free_english_apple: # loops within the rows
        if row[-5] == genre: # picks up index [-5], which is the genre
            print(row[1], ':',row[5]) # picks up the index[1] which is the name and index[5] which is total rating count from the same level
# Out:
#  ---- Navigation ----
#
# Waze - GPS Navigation, Maps & Real-time Traffic : 345046
# Google Maps - Navigation & Transit : 154911
# Geocaching® : 12811
# CoPilot GPS – Car Navigation & Offline Maps : 3582
# ImmobilienScout24: Real Estate Search in Germany : 187
# Railway Route Search : 5
#
#  ---- Reference ----
#
# Bible : 985920
# Dictionary.com Dictionary & Thesaurus : 200047
# Dictionary.com Dictionary & Thesaurus for iPad : 54175
# Google Translate : 26786
# Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran : 18418
# New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition : 17588
# Merriam-Webster Dictionary : 16849
# Night Sky : 12122
# City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE) : 8535
# LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools : 4693
# GUNS MODS for Minecraft PC Edition - Mods Tools : 1497
# Guides for Pokémon GO - Pokemon GO News and Cheats : 826
# WWDC : 762
# Horror Maps for Minecraft PE - Download The Scariest Maps for Minecraft Pocket Edition (MCPE) Free : 718
# VPN Express : 14
# Real Bike Traffic Rider Virtual Reality Glasses : 8
# 教えて!goo : 0
# Jishokun-Japanese English Dictionary & Translator : 0
#
#  ---- Social Networking ----
#
# Facebook : 2974676
# Pinterest : 1061624
# Skype for iPhone : 373519
# Messenger : 351466
# Tumblr : 334293
# WhatsApp Messenger : 287589
# Kik : 260965
# ooVoo – Free Video Call, Text and Voice : 177501
# TextNow - Unlimited Text + Calls : 164963
# Viber Messenger – Text & Call : 164249
# Followers - Social Analytics For Instagram : 112778
# MeetMe - Chat and Meet New People : 97072
# We Heart It - Fashion, wallpapers, quotes, tattoos : 90414
# InsTrack for Instagram - Analytics Plus More : 85535
# Tango - Free Video Call, Voice and Chat : 75412
# LinkedIn : 71856
# Match™ - #1 Dating App. : 60659
# Skype for iPad : 60163
# POF - Best Dating App for Conversations : 52642
# Timehop : 49510
# Find My Family, Friends & iPhone - Life360 Locator : 43877
# Whisper - Share, Express, Meet : 39819
# Hangouts : 36404
# LINE PLAY - Your Avatar World : 34677
# WeChat : 34584
# Badoo - Meet New People, Chat, Socialize. : 34428
# Followers + for Instagram - Follower Analytics : 28633
# GroupMe : 28260
# Marco Polo Video Walkie Talkie : 27662
# Miitomo : 23965
# SimSimi : 23530
# Grindr - Gay and same sex guys chat, meet and date : 23201
# Wishbone - Compare Anything : 20649
# imo video calls and chat : 18841
# After School - Funny Anonymous School News : 18482
# Quick Reposter - Repost, Regram and Reshare Photos : 17694
# Weibo HD : 16772
# Repost for Instagram : 15185
# Live.me – Live Video Chat & Make Friends Nearby : 14724
# Nextdoor : 14402
# Followers Analytics for Instagram - InstaReport : 13914
# YouNow: Live Stream Video Chat : 12079
# FollowMeter for Instagram - Followers Tracking : 11976
# LINE : 11437
# eHarmony™ Dating App - Meet Singles : 11124
# Discord - Chat for Gamers : 9152
# QQ : 9109
# Telegram Messenger : 7573
# Weibo : 7265
# Periscope - Live Video Streaming Around the World : 6062
# Chat for Whatsapp - iPad Version : 5060
# QQ HD : 5058
# Followers Analysis Tool For Instagram App Free : 4253
# live.ly - live video streaming : 4145
# Houseparty - Group Video Chat : 3991
# SOMA Messenger : 3232
# Monkey : 3060
# Down To Lunch : 2535
# Flinch - Video Chat Staring Contest : 2134
# Highrise - Your Avatar Community : 2011
# LOVOO - Dating Chat : 1985
# PlayStation®Messages : 1918
# BOO! - Video chat camera with filters & stickers : 1805
# Qzone : 1649
# Chatous - Chat with new people : 1609
# Kiwi - Q&A : 1538
# GhostCodes - a discovery app for Snapchat : 1313
# Jodel : 1193
# FireChat : 1037
# Google Duo - simple video calling : 1033
# Fiesta by Tango - Chat & Meet New People : 885
# Google Allo — smart messaging : 862
# Peach — share vividly : 727
# Hey! VINA - Where Women Meet New Friends : 719
# Battlefield™ Companion : 689
# All Devices for WhatsApp - Messenger for iPad : 682
# Chat for Pokemon Go - GoChat : 500
# IAmNaughty – Dating App to Meet New People Online : 463
# Qzone HD : 458
# Zenly - Locate your friends in realtime : 427
# League of Legends Friends : 420
# 豆瓣 : 407
# Candid - Speak Your Mind Freely : 398
# 知乎 : 397
# Selfeo : 366
# Fake-A-Location Free ™ : 354
# Popcorn Buzz - Free Group Calls : 281
# Fam — Group video calling for iMessage : 279
# QQ International : 274
# Ameba : 269
# SoundCloud Pulse: for creators : 240
# Tantan : 235
# Cougar Dating & Life Style App for Mature Women : 213
# Rawr Messenger - Dab your chat : 180
# WhenToPost: Best Time to Post Photos for Instagram : 158
# Inke—Broadcast an amazing life : 147
# Mustknow - anonymous video Q&A : 53
# CTFxCmoji : 39
# Lobi : 36
# Chain: Collaborate On MyVideo Story/Group Video : 35
# botman - Real time video chat : 7
# BestieBox : 0
# MATCH ON LINE chat : 0
# niconico ch : 0
# LINE BLOG : 0
# bit-tube - Live Stream Video Chat : 0
#
#  ---- Music ----
#
# Pandora - Music & Radio : 1126879
# Spotify Music : 878563
# Shazam - Discover music, artists, videos & lyrics : 402925
# iHeartRadio – Free Music & Radio Stations : 293228
# SoundCloud - Music & Audio : 135744
# Magic Piano by Smule : 131695
# Smule Sing! : 119316
# TuneIn Radio - MLB NBA Audiobooks Podcasts Music : 110420
# Amazon Music : 106235
# SoundHound Song Search & Music Player : 82602
# Sonos Controller : 48905
# Bandsintown Concerts : 30845
# Karaoke - Sing Karaoke, Unlimited Songs! : 28606
# My Mixtapez Music : 26286
# Sing Karaoke Songs Unlimited with StarMaker : 26227
# Ringtones for iPhone & Ringtone Maker : 25403
# Musi - Unlimited Music For YouTube : 25193
# AutoRap by Smule : 18202
# Spinrilla - Mixtapes For Free : 15053
# Napster - Top Music & Radio : 14268
# edjing Mix:DJ turntable to remix and scratch music : 13580
# Free Music - MP3 Streamer & Playlist Manager Pro : 13443
# Free Piano app by Yokee : 13016
# Google Play Music : 10118
# Certified Mixtapes - Hip Hop Albums & Mixtapes : 9975
# TIDAL : 7398
# YouTube Music : 7109
# Nicki Minaj: The Empire : 5196
# Sounds app - Music And Friends : 5126
# SongFlip - Free Music Streamer : 5004
# Simple Radio - Live AM & FM Radio Stations : 4787
# Deezer - Listen to your Favorite Music & Playlists : 4677
# Ringtones for iPhone with Ringtone Maker : 4013
# Bose SoundTouch : 3687
# Amazon Alexa : 3018
# DatPiff : 2815
# Trebel Music - Unlimited Music Downloader : 2570
# Free Music Play - Mp3 Streamer & Player : 2496
# Acapella from PicPlayPost : 2487
# Coach Guitar - Lessons & Easy Tabs For Beginners : 2416
# Musicloud - MP3 and FLAC Music Player for Cloud Platforms. : 2211
# Piano - Play Keyboard Music Games with Magic Tiles : 1636
# Boom: Best Equalizer & Magical Surround Sound : 1375
# Music Freedom - Unlimited Free MP3 Music Streaming : 1246
# AmpMe - A Portable Social Party Music Speaker : 1047
# Medly - Music Maker : 933
# Bose Connect : 915
# Music Memos : 909
# UE BOOM : 612
# LiveMixtapes : 555
# NOISE : 355
# MP3 Music Player & Streamer for Clouds : 329
# Musical Video Maker - Create Music clips lip sync : 320
# Cloud Music Player - Downloader & Playlist Manager : 319
# Remixlive - Remix loops with pads : 288
# QQ音乐HD : 224
# Blocs Wave - Make & Record Music : 158
# PlayGround • Music At Your Fingertips : 150
# Music and Chill : 135
# The Singing Machine Mobile Karaoke App : 130
# radio.de - Der Radioplayer : 64
# Free Music -  Player & Streamer  for Dropbox, OneDrive & Google Drive : 46
# NRJ Radio : 38
# Smart Music: Streaming Videos and Radio : 17
# BOSS Tuner : 13
# PetitLyrics : 0
#
#  ---- Weather ----
#
# The Weather Channel: Forecast, Radar & Alerts : 495626
# The Weather Channel App for iPad – best local forecast, radar map, and storm tracking : 208648
# WeatherBug - Local Weather, Radar, Maps, Alerts : 188583
# MyRadar NOAA Weather Radar Forecast : 150158
# AccuWeather - Weather for Life : 144214
# Yahoo Weather : 112603
# Weather Underground: Custom Forecast & Local Radar : 49192
# NOAA Weather Radar - Weather Forecast & HD Radar : 45696
# Weather Live Free - Weather Forecast & Alerts : 35702
# Storm Radar : 22792
# QuakeFeed Earthquake Map, Alerts, and News : 6081
# Moji Weather - Free Weather Forecast : 2333
# Hurricane by American Red Cross : 1158
# Forecast Bar : 375
# Hurricane Tracker WESH 2 Orlando, Central Florida : 203
# FEMA : 128
# iWeather - World weather forecast : 80
# Weather - Radar - Storm with Morecast App : 78
# Yurekuru Call : 53
# Weather & Radar : 37
# WRAL Weather Alert : 25
# Météo-France : 24
# JaxReady : 22
# Freddy the Frogcaster's Weather Station : 14
# Almanac Long-Range Weather Forecast : 12
# TodayAir : 0
# wetter.com : 0
# WarnWetter : 0

# %% [markdown]
# - We can clearly see that the genre of *Navigation* is heavily influenced by "Waze - GPS Navigation, Maps & Real-time Traffic", "Google Maps - Navigation & Transit", and "Geocaching®"
# - Apps under the genre of *Social* are heavily influenced by giants like "Facebook", and "Pinterest"
# - Same pattern repeats itself in genre *Music* where "Pandora", "Spotify", and "Shazam" have heavily impacted the average number
# - Even in the *Reference* genre, "Bible" and "Dictionary" completely overwhelm the numbers.

# %% [markdown]
# Lets move onto the PlayStore for now
# #### on Android's PlayStore

# %%
android_header
# Out:
# ['App',
#  'Category',
#  'Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
genres_android = freq_table(free_english_android, 1)
genres_table = []
count2 = 0

for genre in genres_android:
    total = 0
    len_genre = 0
    
    for row in free_english_android:
        genre_app = row[1]
        if genre_app == genre:            
            n_installs = row[5]
            n_installs = n_installs.replace(',', '')
            n_installs = n_installs.replace('+', '')
            total += float(n_installs)
            len_genre += 1
            
    avg_n_installs = total / len_genre
    key_val_tuple2 = (avg_n_installs, genre)
    genres_table.append(key_val_tuple2)
    count2 += avg_n_installs
    
sorted_table2 = sorted(genres_table, reverse = True)

for element in sorted_table2:
    print(element[1], ':', round(element[0]))
# Out:
# COMMUNICATION : 38326063
# VIDEO_PLAYERS : 24790074
# SOCIAL : 23253652
# PHOTOGRAPHY : 17840110
# PRODUCTIVITY : 16772839
# TRAVEL_AND_LOCAL : 13984078
# GAME : 12914436
# TOOLS : 10801391
# NEWS_AND_MAGAZINES : 9549178
# ENTERTAINMENT : 9146923
# BOOKS_AND_REFERENCE : 8767812
# SHOPPING : 7036877
# PERSONALIZATION : 5201483
# FAMILY : 5183204
# WEATHER : 5074486
# SPORTS : 4274689
# HEALTH_AND_FITNESS : 4167457
# MAPS_AND_NAVIGATION : 4056942
# ART_AND_DESIGN : 1986335
# FOOD_AND_DRINK : 1924898
# EDUCATION : 1768500
# BUSINESS : 1704192
# LIFESTYLE : 1437816
# FINANCE : 1387692
# HOUSE_AND_HOME : 1331541
# DATING : 854029
# COMICS : 817657
# AUTO_AND_VEHICLES : 647318
# LIBRARIES_AND_DEMO : 638504
# PARENTING : 542604
# BEAUTY : 513152
# EVENTS : 253542
# MEDICAL : 123065

# %% [markdown]
# **Observations:**
#
# Top 5 Genres in Free English apps of Goolge PlayStore are:
# 1. Communication
# 2. Video Players
# 3. Social Networking
# 4. Photo
# 5. Productivity
#
# Least popular Free English apps of Google's PlayStore: (lowest on top)
# 1. Medical
# 2. Events
# 3. Beauty
# 4. Parenting
# 5. Libraries and Demo

# %% [markdown]
# Lets dig further into the top 5 genres to check whether the Giants are influencing PlayStore's genres or not

# %%
apparently_popular_genres_android = ['COMMUNICATION', 'VIDEO_PLAYERS', 'SOCIAL', 'PHOTOGRAPHY', 'PRODUCTIVITY']
communication = {}
video_players = {}
social = {}
photography = {}
productivity = {}

for genre in apparently_popular_genres_android: # loops for each term in the list
    for row in free_english_android: # loops within the rows
        if row[1] == genre: # picks up index [-5], which is the genre
            n_installs = row[5]
            n_installs = n_installs.replace(',', '')
            n_installs = n_installs.replace('+', '')
            n_installs = int(n_installs)
            # total += float(n_installs)
            #print(row[0], ':',n_installs) # picks up the index[1] which is the name and index[5] which is total rating count from the same level
            if genre == 'COMMUNICATION':
                communication[row[0]] = n_installs
            elif genre == 'VIDEO_PLAYERS':
                video_players[row[0]] = n_installs
            elif genre == 'SOCIAL':
                social[row[0]] = n_installs
            elif genre == 'PHOTOGRAPHY':
                photography[row[0]] = n_installs
            elif genre == 'PRODUCTIVITY':
                productivity[row[0]] = n_installs

# %% [markdown]
# To sort the results, we will have to introduce another function. It will help us to observe the trends orderly

# %%
def sort_dictionary(dictionary, reverse=True):
    '''
    This functions sorts a dictionary into order
    by its values. It does so by switching numberical
    values to keys (i-e. right to left)
    
    Args:
        dictionary: dict. A dictionary with numerical values
        reverse: bool. True by default
        
    Returns:
        List. A list of sets of tuples ordered wrt the values 
        of the inputted dictionary. 
            If reverse = True, default, It returns the list with     
            descending order
            If reverse = False, It returns the list in ascending
            order.
    '''
    table = []
    for item in dictionary.items():
        key_val_tup = (item[1], item[0]) 
        table.append(key_val_tup)
    if reverse == True:
        sort_table_desc = sorted(table, reverse=True)
        return sort_table_desc
    else:
        sort_table_asc = sorted(table)
        return sort_table_asc

# %% [markdown]
# PlayStore's Category `communication`. Ranking for Free English Android's apps

# %%
sort_dictionary(communication)
# Out:
# [(1000000000, 'WhatsApp Messenger'),
#  (1000000000, 'Skype - free IM & video calls'),
#  (1000000000, 'Messenger – Text and Video Chat for Free'),
#  (1000000000, 'Hangouts'),
#  (1000000000, 'Google Chrome: Fast & Secure'),
#  (1000000000, 'Gmail'),
#  (500000000, 'imo free video calls and chat'),
#  (500000000, 'Viber Messenger'),
#  (500000000, 'UC Browser - Fast Download Private & Secure'),
#  (500000000, 'LINE: Free Calls & Messages'),
#  (500000000, 'Google Duo - High Quality Video Calls'),
#  (100000000, 'imo beta free calls and text'),
#  (100000000, 'Yahoo Mail – Stay Organized'),
#  (100000000, 'Who'),
#  (100000000, 'WeChat'),
#  (100000000, 'UC Browser Mini -Tiny Fast Private & Secure'),
#  (100000000, 'Truecaller: Caller ID, SMS spam blocking & Dialer'),
#  (100000000, 'Telegram'),
#  (100000000, 'Opera Mini - fast web browser'),
#  (100000000, 'Opera Browser: Fast and Secure'),
#  (100000000, 'Messenger Lite: Free Calls & Messages'),
#  (100000000, 'Kik'),
#  (100000000, 'KakaoTalk: Free Calls & Text'),
#  (100000000, 'GO SMS Pro - Messenger, Free Themes, Emoji'),
#  (100000000, 'Firefox Browser fast & private'),
#  (100000000, 'BBM - Free Calls & Messages'),
#  (100000000, 'Android Messages'),
#  (50000000, 'free video calls and chat'),
#  (50000000, 'Zalo – Video Call'),
#  (50000000, 'Mail.Ru - Email App'),
#  (50000000, 'Dolphin Browser - Fast, Private & Adblock🐬'),
#  (50000000, 'Contacts'),
#  (50000000, 'CM Browser - Ad Blocker , Fast Download , Privacy'),
#  (50000000, 'Azar'),
#  (10000000, 'myMail – Email for Hotmail, Gmail and Outlook Mail'),
#  (10000000, 'chomp SMS'),
#  (10000000, 'ZenUI Dialer & Contacts'),
#  (10000000, 'Xperia Link™'),
#  (10000000, 'Whoscall - Caller ID & Block'),
#  (10000000, 'WhatsCall Free Global Phone Call App & Cheap Calls'),
#  (10000000, 'WhatsApp Business'),
#  (10000000, 'WEB.DE Mail'),
#  (10000000, 'Voxer Walkie Talkie Messenger'),
#  (10000000, 'TouchPal Keyboard - Fun Emoji & Android Keyboard'),
#  (10000000, 'Text SMS'),
#  (10000000, 'Talkray - Free Calls & Texts'),
#  (10000000, 'Talkatone: Free Texts, Calls & Phone Number'),
#  (10000000, 'Puffin Web Browser'),
#  (10000000, 'Psiphon Pro - The Internet Freedom VPN'),
#  (10000000, 'Portable Wi-Fi hotspot'),
#  (10000000, 'Orfox: Tor Browser for Android'),
#  (10000000, 'Opera Mini browser beta'),
#  (10000000, 'Omlet Chat'),
#  (10000000, 'Mr. Number-Block calls & spam'),
#  (10000000, 'Messenger for SMS'),
#  (10000000, 'MegaFon Dashboard'),
#  (10000000, 'ICQ — Video Calls & Chat Messenger'),
#  (10000000, 'Hiya - Caller ID & Block'),
#  (10000000, 'Hangouts Dialer - Call Phones'),
#  (10000000, 'GroupMe'),
#  (10000000, 'Google Voice'),
#  (10000000, 'Google Allo'),
#  (10000000, 'Glide - Video Chat Messenger'),
#  (10000000, 'GO Notifier'),
#  (10000000, 'GMX Mail'),
#  (10000000, 'Free WiFi Connect'),
#  (10000000, 'Free Adblocker Browser - Adblock & Popup Blocker'),
#  (10000000, 'ExDialer - Dialer & Contacts'),
#  (10000000, 'Discord - Chat for Gamers'),
#  (10000000, 'DU Browser—Browse fast & fun'),
#  (10000000, 'Cricket Visual Voicemail'),
#  (10000000, 'Contacts+'),
#  (10000000, 'Calls Blacklist - Call Blocker'),
#  (10000000, 'CallApp: Caller ID, Blocker & Phone Call Recorder'),
#  (10000000, 'Browser 4G'),
#  (10000000, 'Adblock Browser for Android'),
#  (10000000, 'AT&T Visual Voicemail'),
#  (5000000, 'Your Freedom VPN Client'),
#  (5000000, 'Web Browser & Explorer'),
#  (5000000, 'Sync.ME – Caller ID & Block'),
#  (5000000, 'Skype Lite - Free Video Call & Chat'),
#  (5000000, 'My Vodacom SA'),
#  (5000000, 'My Tele2'),
#  (5000000, 'Microsoft Edge'),
#  (5000000, 'K-9 Mail'),
#  (5000000, 'JusTalk - Free Video Calls and Fun Video Chat'),
#  (5000000, 'Full Screen Caller ID'),
#  (5000000, 'Ear Agent: Super Hearing'),
#  (5000000, 'Daum Mail - Next Mail'),
#  (5000000, 'Chrome Dev'),
#  (5000000, 'Calls & Text by Mo+'),
#  (5000000, 'Caller ID & Call Block - DU Caller'),
#  (5000000, 'Call Free – Free Call'),
#  (5000000, 'Call Control - Call Blocker'),
#  (5000000, 'CM Transfer - Share any files with friends nearby'),
#  (5000000, 'CIA - Caller ID & Call Blocker'),
#  (5000000, 'Brave Browser: Fast AdBlocker'),
#  (5000000, 'Bluetooth Auto Connect'),
#  (5000000, 'AT&T Call Protect'),
#  (1000000, 'mysms SMS Text Messaging Sync'),
#  (1000000, 'mail.com mail'),
#  (1000000, 'Wi-Fi Auto-connect'),
#  (1000000, 'Web Browser for Android'),
#  (1000000, 'WeFi - Free Fast WiFi Connect & Find Wi-Fi Map'),
#  (1000000, 'Vonage Mobile® Call Video Text'),
#  (1000000, 'Virtual Walkie Talkie'),
#  (1000000, 'Video Caller Id'),
#  (1000000, 'True Contact - Real Caller ID'),
#  (1000000, 'TracFone My Account'),
#  (1000000, 'Tiny Call Confirm'),
#  (1000000, 'Should I Answer?'),
#  (1000000, 'Seznam.cz'),
#  (1000000, 'Safest Call Blocker'),
#  (1000000, 'SW-100.tch by Callstel'),
#  (1000000, 'RocketDial Dialer & Contacts'),
#  (1000000, 'PHONE for Google Voice & GTalk'),
#  (1000000, 'Ninesky Browser'),
#  (1000000, 'Newton Mail - Email App for Gmail, Outlook, IMAP'),
#  (1000000, 'My magenta'),
#  (1000000, 'My Vodafone (GR)'),
#  (1000000, 'Messaging+ SMS, MMS Free'),
#  (1000000, 'Lite for Facebook Messenger'),
#  (1000000, 'InBrowser - Incognito Browsing'),
#  (1000000, 'Ghostery Privacy Browser'),
#  (1000000, 'Firefox Focus: The privacy browser'),
#  (1000000, 'Email TypeApp - Mail App'),
#  (1000000, 'DW Contacts & Phone & Dialer'),
#  (1000000, 'ClanPlay: Community and Tools for Gamers'),
#  (1000000, 'Caller ID +'),
#  (1000000, 'Call Blocker - Blacklist, SMS Blocker'),
#  (1000000, 'Call Blocker'),
#  (1000000, 'CB Radio Chat - for friends!'),
#  (1000000, 'Burner - Free Phone Number'),
#  (1000000, 'BBMoji - Your personalized BBM Stickers'),
#  (1000000, 'AntennaPict β'),
#  (1000000, 'All Email Providers'),
#  (1000000, 'Adblock Plus for Samsung Internet - Browse safe.'),
#  (1000000, 'AW - free video calls and chat'),
#  (1000000, 'AT&T Messages for Tablet'),
#  (1000000, '2ndLine - Second Phone Number'),
#  (500000, 'Web Browser'),
#  (500000, 'U - Webinars, Meetings & Messenger'),
#  (500000, 'TownWiFi | Wi-Fi Everywhere'),
#  (500000, 'Talkie - Wi-Fi Calling, Chats, File Sharing'),
#  (500000, 'SolMail - All-in-One email app'),
#  (500000, 'LokLok: Draw on a Lock Screen'),
#  (500000, 'Lightning Web Browser'),
#  (500000, 'FreedomPop Messaging Phone/SIM'),
#  (500000, 'BD Data Plan (3G & 4G)'),
#  (100000, 'WiFi Access Point (hotspot)'),
#  (100000, 'T-Mobile DIGITS'),
#  (100000, 'QRZ Assistant'),
#  (100000, 'Portable Wi-Fi hotspot Free'),
#  (100000, 'PlacarTv Futebol Ao Vivo'),
#  (100000, 'Morse Code Reader'),
#  (100000, 'M star Dialer'),
#  (100000, 'K-@ Mail - Email App'),
#  (100000, 'Goodbox - Mega App'),
#  (100000, 'Everbridge'),
#  (100000, 'Channel 19'),
#  (100000, 'CB On Mobile'),
#  (100000, 'Baby Monitor AV'),
#  (100000, 'BT MeetMe with Dolby Voice'),
#  (100000, 'Antillean Gold Telegram (original version)'),
#  (100000, 'AZ Browser. Private & Download'),
#  (50000, 'X Browser'),
#  (50000, 'N-Com Wizard'),
#  (50000, 'My BF App'),
#  (50000, 'IZ2UUF Morse Koch CW'),
#  (50000, 'HipChat - beta version'),
#  (50000, 'Free Wi-fi HotspoT'),
#  (50000, 'BT Messenger'),
#  (50000, 'BD Internet Packages (Updated)'),
#  (50000, 'AudioBT: BT audio GPS/SMS/Text'),
#  (50000, '3G DZ Configuration'),
#  (10000, 'm:go BiH'),
#  (10000, '[verify-U] VideoIdent'),
#  (10000, 'Ring'),
#  (10000, 'Pocket Prefix Plus'),
#  (10000, 'Mail1Click - Secure Mail'),
#  (10000, 'Jazz Wi-Fi'),
#  (10000, 'Inbox.eu'),
#  (10000, 'Ham Radio Prefixes'),
#  (10000, 'Feel Performer'),
#  (10000, 'Eg Call'),
#  (10000, 'EZ Wifi Notification'),
#  (10000, 'Deaf World DW'),
#  (10000, 'DMR BrandMeister Tool'),
#  (10000, 'ClanHQ'),
#  (10000, 'BT One Phone Mobile App'),
#  (10000, 'BF Browser by Betfilter - Stop Gambling Today!'),
#  (10000, 'BD Dialer'),
#  (10000, 'Ad Blocker Turbo - Adblocker Browser'),
#  (10000, 'Access Point Names'),
#  (10000, '/u/app'),
#  (5000, 'retteMi.ch'),
#  (5000, 'mail.co.uk Mail'),
#  (5000, 'love sms good morning'),
#  (5000, 'Sat-Fi'),
#  (5000, 'Mircules DX Cluster Lite'),
#  (5000, 'Learn Morse Code - G0HYN Learn Morse'),
#  (5000, 'K-9 Material (unofficial)'),
#  (5000, 'Ham DX Cluster & Spots Finder'),
#  (5000, 'DM for WhatsApp'),
#  (5000, 'DM Talk New'),
#  (5000, 'Council Voting Calculator'),
#  (5000, 'CS Browser Beta'),
#  (5000, 'BT One Voice mobile access'),
#  (5000, 'BD Live Call'),
#  (5000, 'AK Phone'),
#  (5000, 'AG Contacts, Lite edition'),
#  (1000, 'cluster.dk'),
#  (1000, 'Sat-Fi Voice'),
#  (1000, 'SMS Sender - sluzba.cz'),
#  (1000, 'ReadyOp DT'),
#  (1000, 'FO AIRBUS TLSE'),
#  (1000, 'FC Browser - Focus Privacy Browser'),
#  (1000, 'EU Council'),
#  (1000, 'DM Tracker'),
#  (1000, 'Call Blocker & Blacklist'),
#  (1000, 'CS Customizer'),
#  (1000, 'CS Browser | #1 & BEST BROWSER'),
#  (1000, 'CQ-Mobile'),
#  (1000, 'BlueDV AMBE'),
#  (1000, 'BQ Partners'),
#  (1000, 'BN MALLORCA Radio'),
#  (1000, 'BK Chat'),
#  (1000, 'BH Mail'),
#  (1000, 'AV Phone'),
#  (1000, 'AU Call Blocker - Block Unwanted Calls Texts 2018'),
#  (500, 'Traffic signs BD'),
#  (500, 'Rádio Sol Nascente DF'),
#  (500, 'Have your say on Europe'),
#  (500, 'ES-1'),
#  (500, 'CW BLE Peripheral Simulator'),
#  (500, 'CQ-Alert'),
#  (500, 'Best Auto Call Recorder Free'),
#  (500, 'ATC Unico BS'),
#  (100, 'tournaments and more.aj.2'),
#  (100, 'chat dz'),
#  (100, '[EF]ShoutBox'),
#  (100, 'Programi podrške EU'),
#  (100, 'MARKET FO'),
#  (100, 'Katalogen.ax'),
#  (100, 'FP Connect'),
#  (100, 'FO STELIA Méaulte'),
#  (100, 'FO SODEXO'),
#  (100, 'FO RCBT'),
#  (100, 'FO PSA Sept-Fons'),
#  (100, 'FO OP St-Nazaire'),
#  (100, 'FO Interim'),
#  (100, 'FO AIRBUS Nantes'),
#  (100, 'EP RSS Reader'),
#  (100, 'EHiN-FH conferenceapp'),
#  (100, 'DG Card'),
#  (100, 'Cy Messenger'),
#  (100, 'Carpooling FH Hagenberg'),
#  (100, 'CW Bluetooth SPP'),
#  (100, 'CJ DVD Rentals'),
#  (100, 'CJ Browser - Fast & Private'),
#  (100, 'CF Chat: Connecting Friends'),
#  (100, 'C W Browser'),
#  (100, "Bee'ah Employee App"),
#  (100, 'BV'),
#  (100, 'Amadeus GR & CY'),
#  (100, 'Aj.Petra'),
#  (50, 'Hyundai CX Conference'),
#  (50, 'DK TEL Dialer'),
#  (50, 'Cb browser'),
#  (50, 'BS-Mobile'),
#  (50, 'AC-BL'),
#  (10, 'ei'),
#  (10, 'Oklahoma Ag Co-op Council'),
#  (10, 'Hlášenírozhlasu.cz'),
#  (10, 'FP Live'),
#  (10, 'FNH Payment Info'),
#  (10, 'FN Web Radio'),
#  (10, 'Ek IRA'),
#  (10, 'EO Mumbai'),
#  (10, 'EJ messenger'),
#  (10, 'DM - The Offical Messaging App'),
#  (10, 'DK Browser'),
#  (10, 'CK Call NEW'),
#  (10, 'Best Browser BD social networking'),
#  (10, 'BJ - Confidential'),
#  (5, 'Test Server SMS FA'),
#  (5, 'Of the wall Arapaho bk'),
#  (1, 'BA SALES')]

# %% [markdown]
# PlayStore's Category `video_players`. Ranking for Free English Android's apps

# %%
sort_dictionary(video_players)
# Out:
# [(1000000000, 'YouTube'),
#  (1000000000, 'Google Play Movies & TV'),
#  (500000000, 'MX Player'),
#  (100000000, 'VivaVideo - Video Editor & Photo Movie'),
#  (100000000, 'VideoShow-Video Editor, Video Maker, Beauty Camera'),
#  (100000000, 'VLC for Android'),
#  (100000000, 'Motorola Gallery'),
#  (100000000, 'Motorola FM Radio'),
#  (100000000, 'Dubsmash'),
#  (50000000, 'Vote for'),
#  (50000000, 'Vigo Video'),
#  (50000000, 'VMate'),
#  (50000000, 'Samsung Video Library'),
#  (50000000, 'Ringdroid'),
#  (50000000, 'MiniMovie - Free Video and Slideshow Editor'),
#  (50000000, 'LIKE – Magic Video Maker & Community'),
#  (50000000, 'KineMaster – Pro Video Editor'),
#  (50000000, 'HD Video Downloader : 2018 Best video mate'),
#  (50000000, 'DU Recorder – Screen Recorder, Video Editor, Live'),
#  (10000000, 'video player for android'),
#  (10000000, 'iMediaShare – Photos & Music'),
#  (10000000, 'YouTube Studio'),
#  (10000000, 'Video Player All Format'),
#  (10000000, 'Video Downloader - for Instagram Repost App'),
#  (10000000, 'Video Downloader'),
#  (10000000, 'Ustream'),
#  (10000000, 'Quik – Free Video Editor for photos, clips, music'),
#  (10000000, 'PowerDirector Video Editor App: 4K, Slow Mo & More'),
#  (10000000, 'Omlet Arcade - Stream, Meet, Play'),
#  (10000000, 'Naruto Shippuden - Watch Free!'),
#  (10000000, 'Music - Mp3 Player'),
#  (10000000, 'Mobizen Screen Recorder for SAMSUNG'),
#  (10000000, 'Magisto Video Editor & Maker'),
#  (10000000, 'Inst Download - Video & Photo'),
#  (10000000, 'HTC Service － DLNA'),
#  (10000000, 'HTC Gallery'),
#  (10000000, 'FrostWire: Torrent Downloader & Music Player'),
#  (10000000, 'FilmoraGo - Free Video Editor'),
#  (10000000, 'Code'),
#  (10000000, 'BitTorrent®- Torrent Downloads'),
#  (10000000, 'BSPlayer FREE'),
#  (10000000, 'All Video Downloader'),
#  (10000000, 'AfreecaTV'),
#  (10000000, 'AZ Screen Recorder - No Root'),
#  (5000000, 'YouCut - Video Editor & Video Maker, No Watermark'),
#  (5000000, 'WiFi Baby Monitor - NannyCam'),
#  (5000000, 'HTC Service—Video Player'),
#  (5000000, 'Droid Zap by Motorola'),
#  (5000000, 'Adobe Premiere Clip'),
#  (5000000, 'ActionDirector Video Editor - Edit Videos Fast'),
#  (1000000, 'video player'),
#  (1000000, 'iSmart DV'),
#  (1000000, 'iPlayIT for YouTube VR Player'),
#  (1000000, 'XX HD Video downloader-Free Video Downloader'),
#  (1000000, 'Vuze Torrent Downloader'),
#  (1000000, 'Video.Guru - Video Maker'),
#  (1000000, 'Video Status'),
#  (1000000, 'Video Editor,Crop Video,Movie Video,Music,Effects'),
#  (1000000, 'VidPlay'),
#  (1000000, 'VUE: video editor & camcorder'),
#  (1000000, 'VPlayer'),
#  (1000000, 'Tencent Video - Supporting the whole network'),
#  (1000000, 'SVT Play'),
#  (1000000, 'Play Tube'),
#  (1000000, 'OnePlus Gallery'),
#  (1000000, 'OBJECTIVE'),
#  (1000000, 'Multiple Videos at Same Time'),
#  (1000000, 'Mobizen Screen Recorder for LG - Record, Capture'),
#  (1000000, 'Iqiyi (for tablet)'),
#  (1000000, 'HD Video Player'),
#  (1000000, 'HD Video Download for Facebook'),
#  (1000000, 'HD Movie Video Player'),
#  (1000000, 'G Guide Program Guide (SOFTBANK EMOBILE WILLCOM version)'),
#  (1000000, 'Funny videos for whatsapp'),
#  (1000000, 'EZCast – Cast Media to TV'),
#  (1000000, 'DU Privacy-hide apps、sms、file'),
#  (1000000, 'DS video'),
#  (1000000, 'DS photo'),
#  (1000000, 'BluTV'),
#  (1000000, 'BSPlayer ARMv7 VFP CPU support'),
#  (1000000, 'AndStream - Streaming Download'),
#  (1000000, 'All Video Downloader 2018'),
#  (1000000, 'AX Player -Nougat Video Player'),
#  (500000, 'Video Player All Format for Android'),
#  (500000, 'GoPlus Cam'),
#  (500000, 'DR TV'),
#  (500000, 'CJ VLC HD Remote (+ Stream)'),
#  (100000, 'amazer - Global Kpop Video Community'),
#  (100000, 'Video Editor'),
#  (100000, 'Video Downloader for FB : Video Download with Link'),
#  (100000, "Sketch 'n' go"),
#  (100000, 'Nero AirBurn'),
#  (100000, 'GoAction'),
#  (100000, 'Free TV series'),
#  (100000, 'Ez Screen Recorder (no ad)'),
#  (100000, 'EZ Web Video Cast | Chromecast'),
#  (100000, 'ES Audio Player ( Shortcut )'),
#  (100000, 'BGCN TV'),
#  (100000, 'AW Screen Recorder No Root'),
#  (100000, 'AB Repeat Player'),
#  (50000, 'dv Prompter'),
#  (50000, 'bgtime.tv'),
#  (50000, 'ES-IPTV'),
#  (50000, 'BR Series'),
#  (50000, 'AX Video Player'),
#  (50000, 'ACTIVEON CX & CX GOLD'),
#  (10000, 'ek tuhi'),
#  (10000, 'W Box VMS'),
#  (10000, 'MelifeCam-M'),
#  (10000, 'HD VideoDownlaoder For Fb : XXVideo Downloader'),
#  (10000, 'HD Video Player (wmv,avi,mp4,flv,av,mpg,mkv)2017'),
#  (10000, 'EZ-SEE'),
#  (10000, 'EZ Usenet for Easynews®'),
#  (10000, 'EZ TV Player'),
#  (10000, 'EML UPnP-AV Control Point'),
#  (10000, 'Downvids Helper - One touch DW'),
#  (10000, 'DG Video Editor'),
#  (10000, 'DG UPnP Player Free'),
#  (10000, 'Casper Ssinema'),
#  (10000, 'BS player remote'),
#  (10000, 'BK News Channel'),
#  (5000, 'W Box VMS HD'),
#  (5000, 'Videos downloader for Facebook:fast fb video saver'),
#  (5000, 'Q-See Plus'),
#  (5000, 'M-Sight Pro'),
#  (5000, 'HD Video Player - Video & MP3 Player | AV Player |'),
#  (5000, 'Furrion ES Control'),
#  (5000, 'EF Sidekick'),
#  (5000, 'DZ Popup Video Player'),
#  (5000, 'DV Lottery Photo'),
#  (5000, 'BR Video Player'),
#  (5000, 'BG video - floating video - background video'),
#  (5000, 'Ay'),
#  (5000, 'A-B repeater'),
#  (5000, '4K VIDEO PLAYER ULTRA HD'),
#  (1000, 'Music for Youtube - Tube Music BG, Red+'),
#  (1000, 'Movie Downloader Torrent : Az Torrent'),
#  (1000, 'EZ game screen recorder with audio 1080P'),
#  (1000, 'CINE BR'),
#  (1000, 'BZ Langenthaler Tagblatt'),
#  (1000, 'BC iptv player'),
#  (1000, 'Ay Sabz Gunbad Waly'),
#  (1000, 'AV-IPTV'),
#  (500, 'YourTube Video Views BG'),
#  (500, 'Video Wallpaper Show'),
#  (500, 'DG Screen Recorder'),
#  (500, 'CX Monthly Tech News'),
#  (500, 'CJ Camcorder'),
#  (500, 'A-Z Screen Recorder -'),
#  (100, 'List iptv FR'),
#  (100, 'EC MANAGER'),
#  (100, 'Bx-WiFi-GI'),
#  (100, 'Bc Vod'),
#  (100, 'BG MUSIC PLAYER - MUSIC PLAYER'),
#  (100, 'AK Lodi Films'),
#  (100, 'AJ Player'),
#  (10, 'CI Stream'),
#  (10, 'Art of F J Taylor')]

# %% [markdown]
# PlayStore's Category `social`. Ranking for Free English Android's apps

# %%
sort_dictionary(social)
# Out:
# [(1000000000, 'Instagram'),
#  (1000000000, 'Google+'),
#  (1000000000, 'Facebook'),
#  (500000000, 'Snapchat'),
#  (500000000, 'Facebook Lite'),
#  (100000000, 'VK'),
#  (100000000, 'Tumblr'),
#  (100000000, 'Tik Tok - including musical.ly'),
#  (100000000, 'Tango - Live Video Broadcast'),
#  (100000000, 'Pinterest'),
#  (100000000, 'LinkedIn'),
#  (100000000, 'Badoo - Free Chat & Dating App'),
#  (100000000, 'BIGO LIVE - Live Stream'),
#  (50000000, 'ooVoo Video Calls, Messaging & Stories'),
#  (50000000, 'Zello PTT Walkie Talkie'),
#  (50000000, 'SKOUT - Meet, Chat, Go Live'),
#  (50000000, 'POF Free Dating App'),
#  (50000000, 'MeetMe: Chat & Meet New People'),
#  (10000000, 'textPlus: Free Text & Calls'),
#  (10000000, 'magicApp Calling & Messaging'),
#  (10000000, 'YouNow: Live Stream Video Chat'),
#  (10000000, 'We Heart It'),
#  (10000000, 'Waplog - Free Chat, Dating App, Meet Singles'),
#  (10000000, 'TextNow - free text + calls'),
#  (10000000, 'Text free - Free Text + Call'),
#  (10000000, 'Text Me: Text Free, Call Free, Second Phone Number'),
#  (10000000, 'Tapatalk - 100,000+ Forums'),
#  (10000000, 'Tagged - Meet, Chat & Dating'),
#  (10000000, 'SayHi Chat, Meet New People'),
#  (10000000, 'Quora'),
#  (10000000, 'Phone Tracker : Family Locator'),
#  (10000000, 'Periscope - Live Video'),
#  (10000000, 'Path'),
#  (10000000, 'Mico- Stranger Chat Random video Chat, Live, Meet'),
#  (10000000, 'Messenger Messenger'),
#  (10000000, 'Messenger'),
#  (10000000, 'Messages, Text and Video Chat for Messenger'),
#  (10000000, 'LiveMe - Video chat, new friends, and make money'),
#  (10000000, 'Legend - Animate Text in Video'),
#  (10000000, 'LOVOO'),
#  (10000000, 'Kate Mobile for VK'),
#  (10000000, 'Jaumo Dating, Flirt & Live Video'),
#  (10000000, 'HTC Social Plugin - Facebook'),
#  (10000000, 'Grindr - Gay chat'),
#  (10000000, 'Free phone calls, free texting SMS on free number'),
#  (10000000, 'Find My Friends'),
#  (10000000, 'Dating App, Flirt & Chat : W-Match'),
#  (10000000, 'Amino: Communities and Chats'),
#  (5000000, 'Who Viewed My Facebook Profile - Stalkers Visitors'),
#  (5000000, 'Whisper'),
#  (5000000, 'Web Browser & Fast Explorer'),
#  (5000000, 'VidStatus app - Status Videos & Status Downloader'),
#  (5000000, 'Timehop'),
#  (5000000, 'Text Free: WiFi Calling App'),
#  (5000000, 'Telegram X'),
#  (5000000, 'SPARK - Live random video chat & meet new people'),
#  (5000000, 'Nextdoor - Local neighborhood news & classifieds'),
#  (5000000, 'Meetup'),
#  (5000000, 'Meet – Talk to Strangers Using Random Video Chat'),
#  (5000000, 'Instachat 😜'),
#  (5000000, 'Hornet - Gay Social Network'),
#  (5000000, 'Hide Something - Photo, Video'),
#  (5000000, 'HOLLA Live: Meet New People via Random Video Chat'),
#  (5000000, 'FunForMobile Ringtones & Chat'),
#  (5000000, 'Frim: get new friends on local chat rooms'),
#  (5000000, 'Fame Boom for Real Followers, Likes'),
#  (5000000, 'Blogger'),
#  (1000000, '💘 WhatsLov: Smileys of love, stickers and GIF'),
#  (1000000, 'pixiv'),
#  (1000000, 'Wishbone - Compare Anything'),
#  (1000000, 'VMate Lite - Funny Short Videos Social Network'),
#  (1000000, 'U LIVE – Video Chat & Stream'),
#  (1000000, 'TwitCasting Live'),
#  (1000000, 'The Messenger App'),
#  (1000000, 'Stickers for Facebook'),
#  (1000000, 'Snaappy – 3D fun AR core communication platform'),
#  (1000000, 'Moment'),
#  (1000000, 'MobilePatrol Public Safety App'),
#  (1000000, 'Messenger Pro'),
#  (1000000, 'Love Sticker'),
#  (1000000, 'Love Images'),
#  (1000000, 'Lesbian Chat & Dating - SPICY'),
#  (1000000, 'Jodel - The Hyperlocal App'),
#  (1000000, 'GUYZ - Gay Chat & Gay Dating'),
#  (1000000, 'Frontback - Social Photos'),
#  (1000000, 'Friendly for Facebook'),
#  (1000000, 'Free Messages, Video, Chat,Text for Messenger Plus'),
#  (1000000, 'FollowMeter for Instagram'),
#  (1000000, 'Fiesta by Tango - Find, Meet and Make New Friends'),
#  (1000000, 'Faster for Facebook Lite'),
#  (1000000, 'Family GPS tracker KidControl + GPS by SMS Locator'),
#  (1000000, 'Facebook Local'),
#  (1000000, 'Facebook Creator'),
#  (1000000, 'EZ Video Download for Facebook'),
#  (1000000, 'Couple - Relationship App'),
#  (1000000, 'Banjo'),
#  (1000000, 'BOO! - Next Generation Messenger'),
#  (1000000, 'B-Messenger Video Chat'),
#  (1000000, 'All Social Networks'),
#  (1000000, '+Download 4 Instagram Twitter'),
#  (500000, 'Web Browser ( Fast & Secure Web Explorer)'),
#  (500000, 'Verdad o Reto'),
#  (500000, 'Swift for Facebook Lite'),
#  (500000, 'Stream - Live Video Community'),
#  (500000, 'Qeek for Instagram - Zoom profile insta DP'),
#  (500000, 'Puffin for Facebook'),
#  (500000, 'Profile Tracker - Who Viewed My Facebook Profile'),
#  (500000, 'Pink Color for Facebook'),
#  (500000, 'Mirrativ: Live Stream Any App'),
#  (500000, 'Greeting Cards & Wishes'),
#  (500000, 'Gayvox - Gay Lesbian Bi Dating'),
#  (500000, 'Fake Chat (Direct Message)'),
#  (500000, 'Daddyhunt: Gay Dating'),
#  (500000, "Bloglovin'"),
#  (100000, 'uCiC- Videos and Photos on demand'),
#  (100000, 'YAY - TBH'),
#  (100000, 'What U See'),
#  (100000, 'The Video Messenger App'),
#  (100000, 'Social network all in one 2018'),
#  (100000, 'See U - Random video chat, video chat'),
#  (100000, 'Phoenix - Facebook & Messenger'),
#  (100000, 'Patook - make platonic friends'),
#  (100000, 'Meet U - Get Friends for Snapchat, Kik & Instagram'),
#  (100000, 'MB Notifications for FB (Free)'),
#  (100000, 'KPOP Amino for K-Pop Entertainment'),
#  (100000, 'KDRAMA Amino for K-Drama Fans'),
#  (100000, 'FutureNet your social app'),
#  (100000, 'Fr Daoud Lamei'),
#  (100000, 'Faster Social for Facebook'),
#  (100000, 'Dr. B.R.Ambedkar'),
#  (100000, 'Dr B R Ambedkar (Jai Bhim)'),
#  (100000, 'Dating.dk'),
#  (100000, 'DP and Status for WhatsApp 2018'),
#  (100000, 'Chat For Strangers - Video Chat'),
#  (100000, 'Blogaway for Android (Blogger)'),
#  (50000, 'Undertale AU Amino'),
#  (50000, 'Rande.cz'),
#  (50000, 'Hashtags For Likes.co'),
#  (50000, 'Golden telegram'),
#  (50000, 'FCB Connect - FC Barcelona'),
#  (50000, 'Equestria Amino for MLP'),
#  (50000, 'EXO-L Amino for EXO Fans'),
#  (50000, 'CP Dialer'),
#  (50000, 'BT Dating -Find your match, help cupid, be social'),
#  (50000, 'Anime et Manga Amino en Français'),
#  (10000, 'Unlimited Group Links - Whatsapp, FB, Telegram'),
#  (10000, 'U-Report'),
#  (10000, 'Stickers for Imo, fb, whatsapp'),
#  (10000, 'Share G - Images Sharing - Wallpapers App'),
#  (10000, 'Mini for Facebook lite'),
#  (10000, 'Mali J'),
#  (10000, 'Lite Messenger for Facebook Lite'),
#  (10000, 'Jamaa Amino for Animal Jam'),
#  (10000, 'Ek Maratha'),
#  (10000, 'Eddsworld Amino'),
#  (10000, 'Digi-TV.ch'),
#  (10000, 'Daily Murli Saar Widget'),
#  (10000, 'DM Me - Chat'),
#  (10000, 'Cyprus Police'),
#  (10000, 'Best DP and Status'),
#  (10000, 'BT Communicator'),
#  (10000, 'BK Traffic Control cum Chart'),
#  (10000, 'Au Pair'),
#  (5000, 'funny Image Comments for FB'),
#  (5000, 'TNEB Bill Online Payment (Tamil)'),
#  (5000, 'TN e Sevai TN EB Bill Patta Citta EC Birth All Hub'),
#  (5000, 'Profile Pictures and DP for Whatsapp'),
#  (5000, 'Instant DP Downloader for Instagram'),
#  (5000, 'Dp for Facebook'),
#  (5000, 'Dp For Whatsapp'),
#  (5000, 'DP Display Pictures Life Quotes Motivational GM'),
#  (5000, 'DM for IG 😘 - Image & Video Saver for Instagram'),
#  (5000, 'DB Event App'),
#  (5000, 'Check Your Visitors on FB ?'),
#  (1000, 'signály.cz'),
#  (1000, 'eChallan Andhra Pradesh (AP)'),
#  (1000, 'Zdravei.BG'),
#  (1000, 'V Bucks ProTips New'),
#  (1000, 'TN EC Online New'),
#  (1000, 'Students.ch'),
#  (1000, 'Sabka Malik Ek Sai'),
#  (1000, 'Noticias DF'),
#  (1000, 'Media Sosial TNI AU'),
#  (1000, 'Join R, Community Engagement'),
#  (1000, 'H letter images'),
#  (1000, 'European Solidarity Corps'),
#  (1000, 'DW Streaming'),
#  (1000, 'DC Comics Amino'),
#  (1000, 'CG Districts'),
#  (1000, 'Black Social'),
#  (1000, 'BR Chat Bot'),
#  (1000, 'BGKontakti Vienna BG Kontakti'),
#  (1000, 'BGKontakti Bayern BG Kontakti'),
#  (1000, 'BG LINKED (BGLINKED)'),
#  (1000, 'Auto DM for Twitter 🔥'),
#  (1000, 'Alarm.fo – choose your info'),
#  (500, 'iCard BD Plus'),
#  (500, 'Downloader plus for FB'),
#  (500, 'DK Murali'),
#  (500, 'DF BugMeNot'),
#  (500, 'Br Browser'),
#  (500, 'BGKontakti London BG Kontakti'),
#  (100, 'i-share AF/KLM (AFKL ishare)'),
#  (100, 'TN Patta /Chitta /EC New'),
#  (100, 'Rejoin Your Ex'),
#  (100, 'Naruto & Boruto FR'),
#  (100, 'Myjob@BM'),
#  (100, 'Movement BE'),
#  (100, 'Message AI - Write Better Messages (Free)'),
#  (100, 'GirlTalk.dk'),
#  (100, 'Frases Cristianas de Esperanza y Fe'),
#  (100, 'Evasion.bz'),
#  (100, 'Eternal Light AG'),
#  (100, 'Discípulos em BH'),
#  (100, 'DV Statistics'),
#  (100, 'DM Storage (for twitter)'),
#  (100, 'CJ Gospel Hour'),
#  (100, 'Alumni BJ'),
#  (50, 'UP EB Bill Payment & Details'),
#  (50, 'FB Advanced Search'),
#  (50, 'EG Way Life'),
#  (50, 'Coupe Adhémar EY 2017'),
#  (10, 'quran-DZ'),
#  (10, 'bm-Events'),
#  (10, 'Reisedealz.eu'),
#  (10, 'Otto DM'),
#  (10, 'News Dz'),
#  (10, 'Hum Ek Hain 2.02'),
#  (10, 'EO RAIPUR'),
#  (10, 'DN Blog'),
#  (10, 'BA 3 Banjarmasin'),
#  (5, 'CB Heroes'),
#  (5, 'C.P. CERVANTES (TOBARRA)'),
#  (1, 'BH Connect'),
#  (1, 'Amleen Ey'),
#  (0, 'Pekalongan CJ')]

# %% [markdown]
# PlayStore's Category `photography`. Ranking for Free English Android's apps

# %%
sort_dictionary(photography)
# Out:
# [(1000000000, 'Google Photos'),
#  (100000000, 'Z Camera - Photo Editor, Beauty Selfie, Collage'),
#  (100000000, 'YouCam Perfect - Selfie Photo Editor'),
#  (100000000, 'YouCam Makeup - Magic Selfie Makeovers'),
#  (100000000, 'Sweet Selfie - selfie camera, beauty cam, photo edit'),
#  (100000000, 'S Photo Editor - Collage Maker , Photo Collage'),
#  (100000000, 'Retrica'),
#  (100000000, 'PicsArt Photo Studio: Collage Maker & Pic Editor'),
#  (100000000, 'PhotoGrid: Video & Pic Collage Maker, Photo Editor'),
#  (100000000, 'Photo Editor Pro'),
#  (100000000, 'Photo Editor Collage Maker Pro'),
#  (100000000, 'Photo Collage Editor'),
#  (100000000, 'LINE Camera - Photo editor'),
#  (100000000, 'Cymera Camera- Photo Editor, Filter,Collage,Layout'),
#  (100000000, 'Candy Camera - selfie, beauty camera, photo editor'),
#  (100000000, 'Camera360: Selfie Photo Editor with Funny Sticker'),
#  (100000000, 'BeautyPlus - Easy Photo Editor & Selfie Camera'),
#  (100000000, 'B612 - Beauty & Filter Camera'),
#  (100000000, 'AR effect'),
#  (50000000, 'Video Editor Music,Cut,No Crop'),
#  (50000000, 'VSCO'),
#  (50000000, 'Square InPic - Photo Editor & Collage Maker'),
#  (50000000, 'Snapseed'),
#  (50000000, 'Selfie Camera - Photo Editor & Filter & Sticker'),
#  (50000000, 'SNOW - AR Camera'),
#  (50000000, 'Pixlr – Free Photo Editor'),
#  (50000000, 'Pic Collage - Photo Editor'),
#  (50000000, 'PhotoWonder: Pro Beauty Photo Editor Collage Maker'),
#  (50000000, 'Photo Lab Picture Editor: face effects, art frames'),
#  (50000000, 'Photo Effects Pro'),
#  (50000000, 'Photo Editor by Aviary'),
#  (50000000, 'Photo Editor Selfie Camera Filter & Mirror Image'),
#  (50000000, 'Motorola Camera'),
#  (50000000, 'MomentCam Cartoons & Stickers'),
#  (50000000, 'MakeupPlus - Your Own Virtual Makeup Artist'),
#  (50000000, 'Keepsafe Photo Vault: Hide Private Photos & Videos'),
#  (50000000, 'InstaSize Photo Filters & Collage Editor'),
#  (50000000, 'InstaBeauty -Makeup Selfie Cam'),
#  (50000000, 'Boomerang from Instagram'),
#  (50000000, 'Adobe Photoshop Express:Photo Editor Collage Maker'),
#  (50000000, 'ASUS Gallery'),
#  (10000000, 'Wondershare PowerCam'),
#  (10000000, 'Sweet Snap - live filter, Selfie photo edit'),
#  (10000000, 'Sweet Camera - Selfie Filters, Beauty Camera'),
#  (10000000, 'Scoompa Video - Slideshow Maker and Video Editor'),
#  (10000000, 'RetroSelfie - Selfie Editor'),
#  (10000000, 'Retro Camera'),
#  (10000000, 'QuickPic - Photo Gallery with Google Drive Support'),
#  (10000000, 'Pixlr-o-matic'),
#  (10000000, 'PixelLab - Text on pictures'),
#  (10000000, 'PhotoScan by Google Photos'),
#  (10000000, 'PhotoLayers〜Superimpose,Eraser'),
#  (10000000, 'PhotoFunia'),
#  (10000000, 'PhotoDirector Photo Editor App'),
#  (10000000, 'Photo Studio'),
#  (10000000, 'Photo Mixer'),
#  (10000000, 'Photo Frames'),
#  (10000000, 'Photo Frame'),
#  (10000000, 'Photo Editor by BeFunky'),
#  (10000000, 'Photo Editor'),
#  (10000000, 'Photo Collage Maker'),
#  (10000000, 'Photo Collage - Layout Editor'),
#  (10000000, 'Photo Collage - InstaMag'),
#  (10000000, 'Phonto - Text on Photos'),
#  (10000000, 'PIP Selfie Camera Photo Editor'),
#  (10000000, 'Open Camera'),
#  (10000000, 'No Crop & Square for Instagram'),
#  (10000000, 'My Photo Keyboard'),
#  (10000000, 'Mirror Photo:Editor Collage (HD)'),
#  (10000000, 'Meitu – Beauty Cam, Easy Photo Editor'),
#  (10000000, 'Love Collage - Photo Editor'),
#  (10000000, 'LightX Photo Editor & Photo Effects'),
#  (10000000, 'HD Camera for Android'),
#  (10000000, 'HD Camera Ultra'),
#  (10000000, 'GoPro (formerly Capture)'),
#  (10000000, 'Free Slideshow Maker & Video Editor'),
#  (10000000, 'Fotor Photo Editor - Photo Collage & Photo Effects'),
#  (10000000, 'Font Studio- Photo Texts Image'),
#  (10000000, 'Flickr'),
#  (10000000, 'Facejjang'),
#  (10000000, 'FaceApp'),
#  (10000000, 'Face Filter, Selfie Editor - Sweet Camera'),
#  (10000000, 'EyeEm - Camera & Photo Filter'),
#  (10000000, 'Color Touch Effects'),
#  (10000000, 'Candy selfie - photo editor, live filter camera'),
#  (10000000, 'Cameringo Lite. Filters Camera'),
#  (10000000, 'Camera360 Lite - Selfie Camera'),
#  (10000000, 'Camera for Android'),
#  (10000000, 'Camera MX - Free Photo & Video Camera'),
#  (10000000, 'Camera FV-5 Lite'),
#  (10000000, 'Bokeh (Background defocus)'),
#  (10000000, 'Blur Image Background'),
#  (10000000, 'Bestie - Camera360 Selfie'),
#  (10000000, 'Beauty Makeup Snappy Collage Photo Editor - Lidow'),
#  (10000000, 'Background Eraser'),
#  (10000000, 'AfterFocus'),
#  (10000000, 'ASUS PixelMaster Camera'),
#  (10000000, 'A+ Gallery - Photos & Videos'),
#  (5000000, 'Visage Lab – face retouch'),
#  (5000000, 'Sweet Camera'),
#  (5000000, 'SuperPhoto - Effects & Filters'),
#  (5000000, 'Story Saver for Instagram'),
#  (5000000, 'Silent Camera [High Quality]'),
#  (5000000, 'Shutterfly: Free Prints, Photo Books, Cards, Gifts'),
#  (5000000, 'Pretty Makeup, Beauty Photo Editor & Snappy Camera'),
#  (5000000, 'Pixgram- video photo slideshow'),
#  (5000000, 'Picture Grid Builder'),
#  (5000000, 'Photo Editor-'),
#  (5000000, 'Muzy - Share photos & collages'),
#  (5000000, 'Moto Photo Editor'),
#  (5000000, 'MIX by Camera360'),
#  (5000000, 'Huji Cam'),
#  (5000000, 'High-Speed Camera (GIF,Burst)'),
#  (5000000, 'HD Camera - Best Cam with filters & panorama'),
#  (5000000, 'HD Camera'),
#  (5000000, 'Ghost In Photo'),
#  (5000000, 'Collage&Add Stickers papelook'),
#  (5000000, 'Change photo background'),
#  (5000000, 'Camera ZOOM FX - FREE'),
#  (5000000, 'Blur Image Background Editor (Blur Photo Editor)'),
#  (5000000, 'Blur Image - DSLR focus effect'),
#  (5000000, 'Adobe Photoshop Fix'),
#  (5000000, 'Adobe Illustrator Draw'),
#  (5000000, 'A Better Camera'),
#  (1000000, 'love'),
#  (1000000, 'XDV'),
#  (1000000, 'Waterfall Photo Frames'),
#  (1000000, 'Video Maker with Photo and Music'),
#  (1000000, 'Unicorn Photo'),
#  (1000000, 'Ultimate Background Eraser'),
#  (1000000, 'TouchNote: Cards & Gifts'),
#  (1000000, 'Thumbnail Maker'),
#  (1000000, 'Snapfish'),
#  (1000000, 'Snap Cat Face Camera'),
#  (1000000, 'Six Pack Abs Photo Editor'),
#  (1000000, 'Selfie Photo Editor'),
#  (1000000, 'Selfie Camera: Beauty Camera, Photo Editor,Collage'),
#  (1000000, 'Samsung SMART CAMERA App'),
#  (1000000, 'Pic Stitch - #1 Collage Maker'),
#  (1000000, 'Phogy, 3D Camera'),
#  (1000000, 'Pencil Photo Sketch-Sketching Drawing Photo Editor'),
#  (1000000, 'Night Photo Frame'),
#  (1000000, 'Mega Photo'),
#  (1000000, 'Makeup Photo Editor: Makeup Camera & Makeup Editor'),
#  (1000000, 'Makeup Editor -Beauty Photo Editor & Selfie Camera'),
#  (1000000, 'LightMeter Free'),
#  (1000000, 'LALALAB prints your photos, photobooks and magnets'),
#  (1000000, 'Kids Photo Frames'),
#  (1000000, 'KVAD Camera +: Selfie, Photo Filter, Grids'),
#  (1000000, 'InstaCam - Camera for Selfie'),
#  (1000000, 'Insave-Download for Instagram'),
#  (1000000, 'Hypocam'),
#  (1000000, 'HD Camera Pro for Android'),
#  (1000000, 'HD Camera - silent shutter'),
#  (1000000, 'HD Camera - Quick Snap Photo & Video'),
#  (1000000, 'FreePrints – Free Photos Delivered'),
#  (1000000, 'Footej Camera'),
#  (1000000, 'FilterGrid - Cam&Photo Editor'),
#  (1000000, 'F-Stop Gallery'),
#  (1000000, 'Ez iCam'),
#  (1000000, 'DSLR Camera Hd Ultra Professional'),
#  (1000000, 'Cut Out : Background Eraser and background changer'),
#  (1000000, 'Canon CameraWindow'),
#  (1000000, 'Camera51 - a smarter camera'),
#  (1000000, 'Camera Pro'),
#  (1000000, 'Blur'),
#  (1000000, 'Beauty Makeup – Photo Makeover'),
#  (1000000, 'BQ Camera'),
#  (1000000, 'Auto Background Changer'),
#  (1000000, 'Afterlight'),
#  (1000000, 'Add Watermark Free'),
#  (1000000, 'Add Text To Photo'),
#  (500000, 'easyFocus'),
#  (500000, 'camera zoom moon'),
#  (500000, 'U Camera : Phone 6s OS 9 style'),
#  (500000, 'Sweet Snap Lite - live filter, Selfie photo editor'),
#  (500000, 'How Do I Look'),
#  (500000, 'Groovebook Photo Books & Gifts'),
#  (500000, 'Garden Photo Frames - Garden Photo Editor'),
#  (500000, 'DU GIF Maker: GIF Maker, Video to GIF & GIF Editor'),
#  (500000, 'Brica BPRO5 AE'),
#  (500000, 'Blurfoto : Auto blur photo background & DSLR focus'),
#  (500000, 'Background Changer & Eraser'),
#  (500000, 'BT Camera'),
#  (100000, 'ez Share Android app'),
#  (100000, 'V.360° Camera'),
#  (100000, 'SportLook'),
#  (100000, 'Picai - Smart AI Camera'),
#  (100000, 'Photo frame'),
#  (100000, 'Gold Teeth Photo Editor'),
#  (100000, 'Fifa World Cup 2018: Photo Frame Editor & DP Maker'),
#  (100000, 'DU Collage Maker - Photo Collage & Grid & Layout'),
#  (100000, 'DSLR Photography Training apps'),
#  (100000, 'DP Maker'),
#  (100000, 'DP Creator for WhatsApp'),
#  (100000, 'Cover Camera for FB'),
#  (100000, 'Camera V7 24 Megapixel'),
#  (100000, 'Black & White Camera - Lovely BW'),
#  (100000, 'B Tiff Viewer'),
#  (100000, 'AZ Camera - Manual Pro Cam'),
#  (100000, '4K Ultra Camera'),
#  (100000, '24 megapixel hd camera'),
#  (50000, 'Wifi Action Camera'),
#  (50000, 'Moony Lab - Print Photos, Books & Magnets ™'),
#  (50000, 'DV Lottery Photo Tool'),
#  (50000, 'DP Status 2017'),
#  (50000, 'BlitzWolf Shutter - BW Shutter'),
#  (50000, 'B&W Photo Filter Editor'),
#  (10000, 'Z Camera'),
#  (10000, 'Square DP For Whatsapp'),
#  (10000, 'Profile w/o crop for Telegram'),
#  (10000, 'Night Camera Blur Effect'),
#  (10000, 'Leica Q'),
#  (10000, 'FN Cam'),
#  (10000, 'FH WiFiCam'),
#  (10000, 'DSLR camera - Auto Focus and Blur Professional'),
#  (10000, 'DP Photo Editor'),
#  (10000, 'DF Night Selfies'),
#  (10000, 'DENVER ACTION CAM 3'),
#  (10000, 'Be Fabulous PHOTO BOOTH'),
#  (10000, 'BL 1-Click Camera - Free'),
#  (5000, 'Insta Square Profile DP'),
#  (5000, 'FL Drone 2'),
#  (5000, 'DP Editor'),
#  (5000, 'CB Edits PNG & CB Backgrounds'),
#  (1000, 'Photo Editor - BPhoto'),
#  (1000, 'Photo BG Changer'),
#  (1000, 'PIP-Camera FN Photo Effect'),
#  (1000, 'Magical Insta DP'),
#  (1000, 'Live DV'),
#  (1000, 'Light Meter - EV'),
#  (1000, 'Leica CL'),
#  (1000, 'FB Photographie'),
#  (1000, 'Dp For FB'),
#  (1000, 'DV-4036 by Somikon'),
#  (1000, 'DS-L4 Viewer'),
#  (1000, 'BK Photography'),
#  (1000, 'Auto Dslr Photo Effect : Auto Focus Effect'),
#  (1000, 'All Types DP & Status Maker'),
#  (1000, 'AEE AP'),
#  (500, 'Selfie With Champion AJ Style'),
#  (500, 'DC-014'),
#  (500, 'CB Hair Png - New Hair Png For CB Editing'),
#  (500, 'BC Camera'),
#  (500, 'AI Image Recognizer (beta)'),
#  (100, 'Wallpaper.cz'),
#  (100, 'LC-DB-LITE'),
#  (100, 'FD Fotografia'),
#  (100, 'DV KING 4K'),
#  (100, 'DV KING'),
#  (100, 'CG Prints'),
#  (100, 'CB VIDEO VISION'),
#  (100, 'Blender BG - Photo Blend With Background'),
#  (100, 'BL Portfolio'),
#  (100, 'Analog BW - Camera filter effect foto film retouch'),
#  (100, 'AJ Cam'),
#  (100, 'A.J. Styles HD Wallpapers 2018'),
#  (50, 'Touch DV'),
#  (50, 'Displaying You VR'),
#  (10, 'i am EB'),
#  (5, 'BG Editor')]

# %% [markdown]
# PlayStore's Category `productivity`. Ranking for Free English Android's apps

# %%
sort_dictionary(productivity)
# Out:
# [(1000000000, 'Google Drive'),
#  (500000000, 'Microsoft Word'),
#  (500000000, 'Google Calendar'),
#  (500000000, 'Dropbox'),
#  (500000000, 'Cloud Print'),
#  (100000000, 'WPS Office - Word, Docs, PDF, Note, Slide & Sheet'),
#  (100000000, 'SwiftKey Keyboard'),
#  (100000000, 'Samsung Notes'),
#  (100000000, 'Microsoft PowerPoint'),
#  (100000000, 'Microsoft Outlook'),
#  (100000000, 'Microsoft OneNote'),
#  (100000000, 'Microsoft OneDrive'),
#  (100000000, 'Microsoft Excel'),
#  (100000000, 'Google Slides'),
#  (100000000, 'Google Sheets'),
#  (100000000, 'Google Keep'),
#  (100000000, 'Google Docs'),
#  (100000000, 'Evernote – Organizer, Planner for Notes & Memos'),
#  (100000000, 'ES File Explorer File Manager'),
#  (100000000, 'ColorNote Notepad Notes'),
#  (100000000, 'CamScanner - Phone PDF Creator'),
#  (100000000, 'Adobe Acrobat Reader'),
#  (50000000, 'myAT&T'),
#  (50000000, 'Verizon Cloud'),
#  (50000000, 'QR Droid'),
#  (50000000, 'My Airtel-Online Recharge, Pay Bill, Wallet, UPI'),
#  (50000000, 'Mobizen Screen Recorder - Record, Capture, Edit'),
#  (50000000, 'MEGA'),
#  (50000000, 'File Browser by Astro (File Manager)'),
#  (50000000, 'Do It Later: Tasks & To-Dos'),
#  (50000000, 'Calculator - unit converter'),
#  (50000000, 'Alarm Clock: Stopwatch & Timer'),
#  (50000000, 'Advanced Task Killer'),
#  (10000000, 'iTranslate Translator & Dictionary'),
#  (10000000, 'aCalendar - Android Phone'),
#  (10000000, 'Wunderlist: To-Do List & Tasks'),
#  (10000000, 'U+Box'),
#  (10000000, 'Todoist: To-do lists for task management & errands'),
#  (10000000, 'S Note'),
#  (10000000, 'Polaris Office - Word, Docs, Sheets, Slide, PDF'),
#  (10000000, 'Notepad & To do list'),
#  (10000000, 'Notepad'),
#  (10000000, 'NQ Mobile Security & Antivirus'),
#  (10000000, 'MyVodafone (India) - Online Recharge & Pay Bills'),
#  (10000000, 'Mobile Security: Antivirus, Web Scan & App Lock'),
#  (10000000, 'Mobile Security & Antivirus'),
#  (10000000, 'Metro name iD'),
#  (10000000, 'LOCX Applock Lock Apps & Photo'),
#  (10000000, 'Keeper: Free Password Manager & Secure Vault'),
#  (10000000, 'Jorte Calendar & Organizer'),
#  (10000000, 'HTC Mail'),
#  (10000000, 'HTC File Manager'),
#  (10000000, 'HTC Calendar'),
#  (10000000, 'Google PDF Viewer'),
#  (10000000, 'Google Assistant'),
#  (10000000, 'Fake Call - Fake Caller ID'),
#  (10000000, 'Easy Voice Recorder'),
#  (10000000, 'Chrome Beta'),
#  (10000000, 'CM FILE MANAGER HD'),
#  (10000000, 'AutoCAD - DWG Viewer & Editor'),
#  (10000000, 'Any.do: To-do list, Calendar, Reminders & Planner'),
#  (10000000, 'AndroZip™ FREE File Manager'),
#  (10000000, 'All-In-One Toolbox: Cleaner, Booster, App Manager'),
#  (10000000, 'AVG Cleaner – Speed, Battery & Memory Booster'),
#  (10000000, 'AT&T Mobile Transfer'),
#  (10000000, 'ASUS SuperNote'),
#  (10000000, 'ASUS Quick Memo'),
#  (10000000, 'ASUS Calling Screen'),
#  (10000000, 'APUS Booster - Space Cleaner & Booster'),
#  (5000000, 'lifebox'),
#  (5000000, 'Yandex.Disk'),
#  (5000000, 'Ultimate Notepad'),
#  (5000000, 'Trello'),
#  (5000000, 'To Do List'),
#  (5000000, 'The Maner'),
#  (5000000, 'QR Scanner & Barcode Scanner 2018'),
#  (5000000, 'PDF Viewer & Book Reader'),
#  (5000000, 'Note Everything'),
#  (5000000, 'My Claro Peru'),
#  (5000000, 'Microsoft Translator'),
#  (5000000, 'MediaFire'),
#  (5000000, 'Keep My Notes - Notepad & Memo'),
#  (5000000, 'Ginger Keyboard - Emoji, GIFs, Themes & Games'),
#  (5000000, 'G Cloud Backup'),
#  (5000000, 'EBookDroid - PDF & DJVU Reader'),
#  (5000000, 'DigiCal Calendar Agenda'),
#  (5000000, 'Content Transfer'),
#  (5000000, 'Clean My Android'),
#  (5000000, 'Calendar Widget Month + Agenda'),
#  (5000000, 'Business Calendar 2'),
#  (5000000, 'Archos File Manager'),
#  (1000000, 'pCloud: Free Cloud Storage'),
#  (1000000, 'e-Boks.dk'),
#  (1000000, 'Ultimate Chest Tracker'),
#  (1000000, 'Today Calendar 2017'),
#  (1000000, 'To-Do List Widget'),
#  (1000000, 'To-Do Calendar Planner'),
#  (1000000, 'To Do Reminder with Alarm'),
#  (1000000, 'Time Recording - Timesheet App'),
#  (1000000, 'TickTick: To Do List with Reminder, Day Planner'),
#  (1000000, 'S’more - Earn Cash Rewards'),
#  (1000000, 'SugarSync'),
#  (1000000, 'Sticky Note + : Sync Notes'),
#  (1000000, 'Squid - Take Notes & Markup PDFs'),
#  (1000000, 'Solid Explorer File Manager'),
#  (1000000, 'Solid Explorer Classic'),
#  (1000000, 'Smart File Manager'),
#  (1000000, 'Simple Notepad'),
#  (1000000, 'Security & Privacy'),
#  (1000000, 'Resume Free'),
#  (1000000, 'Pushbullet - SMS on PC'),
#  (1000000, 'Power Booster - Junk Cleaner & CPU Cooler & Boost'),
#  (1000000, 'Planner Pro-Personal Organizer'),
#  (1000000, 'Phone Clean Best Speed Booster'),
#  (1000000, 'NoteToDo. Notes. To do list'),
#  (1000000, 'New Calendar'),
#  (1000000, 'Můj T-Mobile Business'),
#  (1000000, 'MyMTN'),
#  (1000000, 'Multiling O Keyboard + emoji'),
#  (1000000, 'Microsoft To-Do: List, Task & Reminder'),
#  (1000000, 'Mahalaxmi Dindarshika 2018'),
#  (1000000, 'Lyra Virtual Assistant'),
#  (1000000, 'Loop - Habit Tracker'),
#  (1000000, 'JotterPad - Writer, Screenplay, Novel'),
#  (1000000, 'IFTTT'),
#  (1000000, "Hacker's Keyboard"),
#  (1000000, 'Google AdSense'),
#  (1000000, 'Extreme- Personal Voice Assistant'),
#  (1000000, 'Epson iProjection'),
#  (1000000, 'Emoji Android L Keyboard'),
#  (1000000, 'EX File Explorer File Manager'),
#  (1000000, 'ES Material Theme for Pro'),
#  (1000000, 'Do it (Tomorrow)'),
#  (1000000, 'Dashlane Free Password Manager'),
#  (1000000, 'DS file'),
#  (1000000, 'Cozi Family Organizer'),
#  (1000000, 'Chrome Canary (Unstable)'),
#  (1000000, 'Chelsea FC Official Keyboard'),
#  (1000000, 'Calendar+ Schedule Planner App'),
#  (1000000, 'Cal - Google Calendar + Widget'),
#  (1000000, 'CY Security Antivirus Cleaner'),
#  (1000000, 'Avast Wi-Fi Finder'),
#  (1000000, 'Amazon Drive'),
#  (1000000, 'Adobe Fill & Sign: Easy PDF Form Filler'),
#  (1000000, 'Adblock Fast'),
#  (1000000, 'ALL-IN-ONE PACKAGE TRACKING'),
#  (1000000, 'AL Voice Recorder'),
#  (500000, 'Ultimate Calculator for CR'),
#  (500000, 'Time Planner - Schedule, To-Do List, Time Tracker'),
#  (500000, 'T-Mobile Content Transfer'),
#  (500000, 'Q Link Wireless Zone'),
#  (500000, 'Planning Center Services'),
#  (500000, 'Official QR Code® Reader "Q"'),
#  (500000, 'My Effectiveness: To do, Tasks'),
#  (500000, 'Memory Helper - To do list, Notepad, Notes, Memo'),
#  (500000, 'ES Holo Theme for Pro'),
#  (500000, 'DS cam'),
#  (500000, 'Ad Detect Plugin - Handy Tool'),
#  (500000, 'A-Z App Store'),
#  (500000, '7 Weeks - Habit & Goal Tracker'),
#  (100000, 'cm, mm to inch, feet converter tool'),
#  (100000, 'Unclouded - Cloud Manager'),
#  (100000, 'Total AV'),
#  (100000, 'TIMBER AD FILTER - Very useful ad block app'),
#  (100000, 'Synology Drive'),
#  (100000, 'Resume Builder and CV maker app'),
#  (100000, 'Pocket RxTx Free'),
#  (100000, 'MyLifeOrganized: To-Do List'),
#  (100000, 'Inch/cm/Foot Conversion'),
#  (100000, 'Ike - To-Do List, Task List'),
#  (100000, 'IQ Test'),
#  (100000, 'IDM for Facebook ★ Downloader'),
#  (100000, 'IDM Internet Download Manager'),
#  (100000, 'Goal Meter: Goal Tracker, Habit Changer,To-Do List'),
#  (100000, 'Future Cloud'),
#  (100000, 'Friday: Smart Personal Assistant'),
#  (100000, 'File Explorer'),
#  (100000, 'Exército Brasileiro'),
#  (100000, 'EZ Switch Widget'),
#  (100000, 'EZ File Manager(Root Explorer)'),
#  (100000, 'ES Disk Analyzer - Storage Space'),
#  (100000, 'Dz Dinars Numbers to letters'),
#  (100000, 'Dr.Android Repair Master 2017'),
#  (100000, 'Download Manager Pro FREE'),
#  (100000, 'Do Not Disturb'),
#  (100000, 'DS note'),
#  (100000, 'Clean My House – Chore To Do List, Task Scheduler'),
#  (100000, 'Calculator L'),
#  (100000, 'Bits Watch Face'),
#  (100000, 'Best Applock - Locker & No Ads'),
#  (100000, '2Do - Reminders, To-do List & Notes'),
#  (50000, 'WiFi-o-Matic'),
#  (50000, 'WFVS 2018 | WhatApp Full Video Status & Downloader'),
#  (50000, 'U Assist - Screen Mirroring & Sharing App'),
#  (50000, 'To-do list'),
#  (50000, 'Safe Notes - Secure Ad-free notepad'),
#  (50000, 'SH Script Runner'),
#  (50000, 'Numbers Into Words'),
#  (50000, 'My C Spire'),
#  (50000, 'MultiMessage for FB Messenger'),
#  (50000, 'Inputting Plus: Ctrl + Z/F/C/V'),
#  (50000, 'EZ Display'),
#  (50000, 'ESLock File Recovery Lite'),
#  (50000, 'CTRL-F - Search the real world'),
#  (50000, 'BJ Memo Widget'),
#  (50000, 'Add-On: Alcatel (h)'),
#  (10000, 'ai.Bot Box'),
#  (10000, 'Wi-Fi Networks'),
#  (10000, 'Trimble DL'),
#  (10000, 'Trimble Ag Mobile'),
#  (10000, 'Tap N Pay'),
#  (10000, 'Solar CT PV System Power'),
#  (10000, 'Remote Control For All AC - Universal Remote'),
#  (10000, 'N Files - File Manager & Explorer'),
#  (10000, 'Mix Tank – Tank Mixing Ag App'),
#  (10000, 'Larry H Miller Automotive'),
#  (10000, 'Eurostat Country Profiles'),
#  (10000, 'Electricity Bill Calculator BD'),
#  (10000, 'EZ Inspections'),
#  (10000, 'EC Taximeter'),
#  (10000, 'DG Report Reminder'),
#  (10000, 'Curriculum Vitae - Resume CV'),
#  (10000, 'CD Library'),
#  (10000, 'Alt-C'),
#  (5000, 'Turbo AI™ - Personal assistant'),
#  (5000, 'Resume & CV Creator by Desygner'),
#  (5000, 'R-net for Android'),
#  (5000, 'Mind Map AR, Augmented Reality ARCore Mind Mapping'),
#  (5000, 'EU Economy'),
#  (5000, 'ESS Mobile for AE'),
#  (5000, 'CG - Calendars Add-On'),
#  (5000, 'Bomb and Nade Timer for CS:GO'),
#  (5000, 'BA Calculator'),
#  (5000, 'Air Conditioner Maintenance'),
#  (5000, 'Add-On: bq (a)'),
#  (5000, 'AP ENPS Mobile'),
#  (1000, 'Simple EV Calc'),
#  (1000, 'Sai Baba - Sabka Malik Ek'),
#  (1000, 'Safe Wi-Fi'),
#  (1000, 'Puck AI Personal Assistant Robot'),
#  (1000, 'Professional AV Solution & Products information'),
#  (1000, 'New Holland Agriculture T5 EC'),
#  (1000, 'My CU - Caucasus University'),
#  (1000, 'Krypton by krypt.co'),
#  (1000, 'Fayr - Co-Parenting Simplified'),
#  (1000, 'FQ METER'),
#  (1000, 'FL House'),
#  (1000, 'EZ Notes Lite'),
#  (1000, 'EF Calculator'),
#  (1000, 'DS-20000S'),
#  (1000, 'DG Phone Call Task Switcher'),
#  (1000, 'DB Manager'),
#  (1000, 'Commission Manager'),
#  (1000, 'CircleCI Viewer'),
#  (1000, 'Charlotte County, FL'),
#  (1000, 'Calendars (En, Bn, Ar)'),
#  (1000, 'CG - Conference Call Add-On'),
#  (1000, "CA World '17"),
#  (1000, 'BG+Phone Backup'),
#  (1000, 'BD Field Force'),
#  (1000, 'BD Attendance'),
#  (1000, 'Ag PhD Soils'),
#  (1000, 'Add-On: bq (c)'),
#  (1000, 'Add-On: bq (b)'),
#  (1000, 'AI Sight'),
#  (500, 'Tips Microsoft Dynamics Ax'),
#  (500, 'Q Actions - Digital Assistant'),
#  (500, 'IP address BW'),
#  (500, 'Florida Cooling Supply HVAC'),
#  (500, 'Fast Notes FJ'),
#  (500, 'Ek Vote'),
#  (500, 'EY Events Switzerland'),
#  (500, 'EY ATL Fuel Calculator'),
#  (500, 'DT Manager'),
#  (500, 'DN Events'),
#  (500, 'CP Connect 2.0'),
#  (500, "CJ Wilson's ZoomZoomnation"),
#  (500, 'BZ Dealer'),
#  (100, 'iReadMe'),
#  (100, 'ec-Work'),
#  (100, 'eG Monitor'),
#  (100, 'Town of Princeton, BC'),
#  (100, 'Tips & Tricks Dynamics AX 365'),
#  (100, 'Thistletown CI'),
#  (100, 'Somos CG'),
#  (100, 'SCS eC'),
#  (100, 'RoutePlan.cz'),
#  (100, 'Register.ca Mobile'),
#  (100, 'MiAI (Artificial Intelligence) Assistant'),
#  (100, 'Mat|r viewer'),
#  (100, 'K-App Mitarbeiter Galeria Kaufhof'),
#  (100, 'J. Polep Plus Mobile'),
#  (100, 'Fort Myers FL'),
#  (100, 'ES Billing System (Offline App)'),
#  (100, 'EP Home Energy Hub'),
#  (100, 'EG'),
#  (100, 'EF Staff'),
#  (100, 'DG Users'),
#  (100, 'DF-Server Mobile'),
#  (100, 'Cx Wize'),
#  (100, "CJ'S TIRE AND AUTO INC."),
#  (100, 'CI Time'),
#  (100, 'CI Remote for Go'),
#  (100, 'CI CAFETERIAS UBER'),
#  (100, 'Builder (by Engineer.ai)'),
#  (100, 'BW-IVMS'),
#  (100, 'BV Mobile Apps'),
#  (100, 'Ag Trucking Mobile App'),
#  (100, 'Ag Guardian'),
#  (50, 'My Ag Report'),
#  (50, 'MY GULFPORT FL'),
#  (50, 'EY Team Connect'),
#  (50, 'EB Scanner'),
#  (50, 'CX Summit'),
#  (50, 'CT CONNECT'),
#  (50, 'CONNECT: The Mobile CX Summit'),
#  (50, 'CE SODEXO PASS FRANCE'),
#  (50, 'BN DB1 App'),
#  (50, 'BAMMS for BM 1Park'),
#  (10, 'SKIN BK'),
#  (10, 'PLMGSS FR'),
#  (10, 'My CG'),
#  (10, 'MinT BI'),
#  (10, 'EU Brazil Green Business Forum'),
#  (10, 'ER Assist'),
#  (10, 'EP Cloud'),
#  (10, 'EI!'),
#  (10, 'EC QR'),
#  (10, 'DV Web Design Tips'),
#  (10, 'CQ Ukraine'),
#  (10, 'BW t&t'),
#  (10, 'BW Ultra'),
#  (10, 'BN Inscript Improved Keyboard'),
#  (10, 'BN Inscript Improved Input keyboard'),
#  (10, 'BM Interventi'),
#  (10, 'BAMMS for BM SQ'),
#  (10, 'AQ Guards'),
#  (10, 'APagri CD'),
#  (10, 'ACCEPT CE MARKING'),
#  (5, "Shaggy's DM Assistant"),
#  (5, 'FK Events'),
#  (1, 'EC Sampler'),
#  (1, 'DZ Register'),
#  (1, 'DT Freight'),
#  (1, 'CQ Electrical Group')]

# %%
under_100_m = []

for app in free_english_android:
    n_installs = app[5]
    n_installs = n_installs.replace(',', '')
    n_installs = n_installs.replace('+', '')
    if (app[1] == 'COMMUNICATION') and (float(n_installs) < 100000000):
        under_100_m.append(float(n_installs))
        
sum(under_100_m) / len(under_100_m)
# Out:
# 3593510.3486590036

# %%
display_table(free_english_android, -5)
# Out:
# Everyone : 81.43969310617173
# Teen : 11.057204106961525
# Mature 17+ : 4.185941554778292
# Everyone 10+ : 3.2607469254202868
# Adults only 18+ : 0.033848584000902626
# Unrated : 0.022565722667268417

# %% [markdown]
# ### Inferences:
# 1. The terms used to define the genres in each Dataset are not standard and even ambigious to a considerable extent. Lets look at the most popular Genres of both Stores again.
#     - In AppStore, following genres of free english apps are on the top
#         1. Navigation
#         2. Reference
#         3. Social Networking
#         4. Music
#         5. Weather
#     - Whereas in PlayStore, following are the genres of free english apps are the most popular:
#         1. Communication
#         2. Video Players
#         3. Social Networking
#         4. Photo
#         5. Productivity
#
# If we compare the lists, `Social Networking` and `Music` are not entirely exclusive of `Communication` and `Video Players`.
#
# 2. However, We can clearly see that the genre `Navigation` that tops the AppStore's Free English genres has a very low ranking on PlayStore's Free English apps' genres. Similarly, `Productivity` ranks among the highest in PlayStore but has a very low ranking on AppStore's ranking
#
# 3. Both `Education` and `Business` genress perform poorly on popularity charts of Free English apps of both, AppStore and PlayStore

# %% [markdown]
# ## Conclusions:
# - Based on the above analysis, the Social (networking) Genre is the most popular with AppStore and GooglePlayStore's free english Apps with 10.8%, 9.88% of most popular apps.
# - Another encouraging factor to consider the social genre is that it is quite under representated, as it can be seen that on IOS only 3.28% apps, and on Android, only 2.66% of total free english apps are there in their respective app stores
